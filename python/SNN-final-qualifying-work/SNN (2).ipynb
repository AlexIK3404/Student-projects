# %%
# !pip install --upgrade -q git+https://github.com/AlexIK3404/spikingjelly
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for spikingjelly (setup.py) ... done

# %% [markdown]
# Путь к библиотеке - /usr/local/lib/python3.12/dist-packages/spikingjelly

# %% [markdown]
# Для изменения метода интегрирования вносятся модификации в метод neuronal_charge классов LIFNode и IzhikevichNode

# %% [markdown]
# # 1. Импорт библиотек

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader

import numpy as np
import pandas as pd

from torchvision import datasets, transforms

from spikingjelly.activation_based import surrogate, functional, encoding
from spikingjelly.activation_based import neuron as neuron

import random
import time
import csv
import math
from statistics import mean, stdev
from dataclasses import dataclass

# %% [markdown]
# # 2. Установка сида

# %%
def set_seed(seed: int):
    # Python-level RNG (используется модулем random: random.random(), random.shuffle() и т.д.)
    random.seed(seed)

    # NumPy RNG (np.random.*)
    np.random.seed(seed)

    # PyTorch CPU RNG — влияет на все операции, генерирующие случайные числа на CPU
    # (torch.rand, torch.randn инициализация весов на CPU и т.д.)
    torch.manual_seed(seed)

    # PyTorch CUDA RNG — задаёт seed для всех GPU-устройств, если есть CUDA.
    # Это влияет на всё случайное, выполняемое на GPU (torch.rand на cuda и т.д.)
    torch.cuda.manual_seed_all(seed)

    # Настройки cuDNN:
    # - deterministic=True просит cuDNN использовать детерминированные алгоритмы, когда это возможно.
    # - benchmark=False выключает автоподбор (autotuner), который подбирает «лучший» (но иногда недетерминированный)
    #   алгоритм для текущего ввода/устройства.
    # Это помогает воспроизводимости, но может снизить производительность и/или выбросить некоторые ускоренные реализации.
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# # 3. Параметры эксперимента

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print('DEVICE =', DEVICE)

#T_bio = 5            # условное время симуляции, число временных шагов T = T_bio / dt
T = 50                # число временных шагов
dt = 0.1              # шаг интегрирования
BATCH_SIZE = 128
LR = 1e-3
EPOCHS = 20
SEEDS = [0]           # список сидов для усреднения
# Out:
# DEVICE = cuda

# %% [markdown]
# # 4. Датасет MNIST + Poisson-кодирование

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])

train_set = datasets.MNIST(
    root='./data', train=True, download=True, transform=transform
)

test_set = datasets.MNIST(
    root='./data', train=False, download=True, transform=transform
)

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
test_loader  = DataLoader(test_set,  batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

encoder = encoding.PoissonEncoderWithDt(dt=dt, method='exact', seed=42)
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 60.5MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 2.01MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 15.1MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 3.08MB/s]

# %% [markdown]
# # 5. SNN с нейроном Ижикевича

# %%
class IzhSNN(nn.Module):
    def __init__(self, integrator='euler', dt=1.0, T=50):
        super().__init__()

        self.fc1 = nn.Linear(28 * 28, 256, bias=False)

        # передаём integrator в нейрон
        self.neuron1 = neuron.IzhikevichNode(
            tau=2.0,
            v_c=0.8,
            a0=1.0,
            v_threshold=1.0,
            v_reset=0.0,
            v_rest=-0.1,
            w_rest=0.0,
            tau_w=2.0,
            a=0.02,
            b=0.2,
            surrogate_function=surrogate.Sigmoid(),
            integrator=integrator,
            dt=dt
        )

        self.fc_out = nn.Linear(256, 10, bias=False)

    def forward(self, x):
        # x: [B, 1, 28, 28]
        out_max = None

        # для совместимости с encoder, используем плоскую форму
        x_flat = x.view(x.size(0), -1)

        # T = int(T_bio / dt)

        for t in range(T):
            # encoder принимает плоский вход
            x_t = encoder(x_flat)            # shape [B, 28*28]
            h = self.fc1(x_t)
            s = self.neuron1(h)              # спайки
            out = self.fc_out(s)
            out_max = out if out_max is None else torch.maximum(out_max, out)

        return out

# %%
class LIFSNN(nn.Module):
    def __init__(self, integrator='euler', dt=1.0, T=50):
        super().__init__()

        self.fc1 = nn.Linear(28 * 28, 256, bias=False)

        # LIF node (интегратор можно задавать: 'euler' или 'exp')
        self.neuron1 = neuron.LIFNode(
            tau=2.0,
            decay_input=True,
            v_threshold=1.0,
            v_reset=0.0,
            surrogate_function=surrogate.Sigmoid(),
            integrator=integrator,
            dt=dt
        )

        self.fc_out = nn.Linear(256, 10, bias=False)

    def forward(self, x):
        out_max = None
        x_flat = x.view(x.size(0), -1)
        # T = int(T_bio / dt)

        for t in range(T):
            x_t = encoder(x_flat)
            h = self.fc1(x_t)
            s = self.neuron1(h)
            out = self.fc_out(s)
            out_max = out if out_max is None else torch.maximum(out_max, out)

        return out

# %% [markdown]
# # 6. Обучение

# %%
def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    correct = 0
    total = 0
    total_loss = 0.0

    for x, y in loader:
        x = x.to(DEVICE)
        y = y.to(DEVICE)

        optimizer.zero_grad()
        functional.reset_net(model)

        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        pred = out.argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.size(0)

    return total_loss / len(loader), 100. * correct / total

# %% [markdown]
# # 7. Тестирование

# %%
@torch.no_grad()
def evaluate(model, loader):
    model.eval()
    correct = 0
    total = 0

    for x, y in loader:
        x = x.to(DEVICE)
        y = y.to(DEVICE)

        functional.reset_net(model)
        out = model(x)
        pred = out.argmax(dim=1)

        correct += (pred == y).sum().item()
        total += y.size(0)

    return 100. * correct / total

# %% [markdown]
# # 8. Запуск одного эксперимента (один seed)

# %%
def run_experiment(model_cls, integrator, EPOCHS, seed: int, dt: float, T:float):
    print(f'\n=== Model {model_cls.__name__} integrator={integrator} seed={seed} dt={dt} ===')

    set_seed(seed)

    model = model_cls(integrator=integrator, dt=dt, T=T).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LR)
    criterion = nn.CrossEntropyLoss()

    t0 = time.time()
    for epoch in range(EPOCHS):
        encoder.reset(seed=seed + epoch, device=torch.device(DEVICE))
        train_loss, train_acc = train_one_epoch(
            model, train_loader, optimizer, criterion
        )
        encoder.reset(seed=seed + 10_000 + epoch, device=torch.device(DEVICE))
        test_acc = evaluate(model, test_loader)

        elapsed = time.time() - t0
        print(
            f'Epoch {epoch:02d}: loss={train_loss:.4f}, train_acc={train_acc:.2f}%, test_acc={test_acc:.2f}%, elapsed={elapsed/60:.2f}min'
        )

    return test_acc

# %% [markdown]
# # 9. Запуск серии экспериментов

# %%
def run_grid_experiments(SEEDS, dt, T, EPOCHS=20):
    results_table = []
    # конфигурации: (модель, список интеграторов)
    grid = [
        (IzhSNN, ['euler', 'symplectic']),
        (LIFSNN, ['euler', 'exp']),
    ]

    for model_cls, integrators in grid:
        for integrator in integrators:
            accs = []
            for seed in SEEDS:
                acc = run_experiment(model_cls, integrator, EPOCHS, seed, dt, T)
                accs.append(acc)
            mean_acc = mean(accs)
            std_acc = stdev(accs) if len(accs) > 1 else 0.0
            print(f'--> {model_cls.__name__} integrator={integrator}: mean={mean_acc:.2f}% std={std_acc:.2f}% over seeds={SEEDS}')
            results_table.append({
                'model': model_cls.__name__,
                'integrator': integrator,
                'seeds': SEEDS,
                'accs': accs,
                'mean_acc': mean_acc,
                'std_acc': std_acc
            })

    # сохранить в CSV
    csv_file = 'results.csv'
    with open(csv_file, mode='w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(['model', 'integrator', 'seeds', 'accs', 'mean_acc', 'std_acc'])
        for r in results_table:
            writer.writerow([r['model'], r['integrator'], r['seeds'], r['accs'], r['mean_acc'], r['std_acc']])

    print(f'\nAll experiments finished. Results saved to {csv_file}')
    return results_table

# %% [markdown]
# # 10. Эксперименты с фиксированным T_bio

# %%
if __name__ == "__main__":
    dt=0.5
    encoder.reset(dt=dt)
    results = run_grid_experiments()
    # печать финальной сводки
    for r in results:
        print(r)
# Out:
# === Model IzhSNN integrator=euler seed=0 dt=0.5 ===
# Epoch 00: loss=1.0698, train_acc=71.59%, test_acc=81.20%, elapsed=0.24min
# Epoch 01: loss=0.5992, train_acc=82.49%, test_acc=84.74%, elapsed=0.47min
# Epoch 02: loss=0.5316, train_acc=84.24%, test_acc=85.21%, elapsed=0.71min
# Epoch 03: loss=0.4926, train_acc=85.37%, test_acc=86.50%, elapsed=0.95min
# Epoch 04: loss=0.4565, train_acc=86.45%, test_acc=87.59%, elapsed=1.18min
# Epoch 05: loss=0.4331, train_acc=87.23%, test_acc=87.66%, elapsed=1.41min
# Epoch 06: loss=0.4149, train_acc=87.64%, test_acc=88.28%, elapsed=1.64min
# Epoch 07: loss=0.4011, train_acc=88.17%, test_acc=88.85%, elapsed=1.88min
# Epoch 08: loss=0.3840, train_acc=88.57%, test_acc=88.97%, elapsed=2.12min
# Epoch 09: loss=0.3763, train_acc=88.80%, test_acc=89.61%, elapsed=2.35min
# Epoch 10: loss=0.3649, train_acc=89.27%, test_acc=89.46%, elapsed=2.58min
# Epoch 11: loss=0.3518, train_acc=89.60%, test_acc=90.06%, elapsed=2.82min
# Epoch 12: loss=0.3442, train_acc=89.90%, test_acc=89.96%, elapsed=3.05min
# Epoch 13: loss=0.3381, train_acc=89.97%, test_acc=90.41%, elapsed=3.29min
# Epoch 14: loss=0.3317, train_acc=90.14%, test_acc=89.85%, elapsed=3.52min
# Epoch 15: loss=0.3266, train_acc=90.28%, test_acc=90.31%, elapsed=3.75min
# Epoch 16: loss=0.3194, train_acc=90.69%, test_acc=90.77%, elapsed=3.99min
# Epoch 17: loss=0.3142, train_acc=90.75%, test_acc=90.91%, elapsed=4.22min
# Epoch 18: loss=0.3127, train_acc=90.63%, test_acc=90.86%, elapsed=4.46min
# Epoch 19: loss=0.3077, train_acc=90.92%, test_acc=91.16%, elapsed=4.69min
# --> IzhSNN integrator=euler: mean=91.16% std=0.00% over seeds=[0]
#
# === Model IzhSNN integrator=symplectic seed=0 dt=0.5 ===
# Epoch 00: loss=1.0532, train_acc=71.92%, test_acc=81.56%, elapsed=0.23min
# Epoch 01: loss=0.5872, train_acc=82.67%, test_acc=84.77%, elapsed=0.47min
# Epoch 02: loss=0.5195, train_acc=84.55%, test_acc=85.22%, elapsed=0.70min
# Epoch 03: loss=0.4771, train_acc=85.97%, test_acc=86.82%, elapsed=0.94min
# Epoch 04: loss=0.4476, train_acc=86.65%, test_acc=87.42%, elapsed=1.17min
# Epoch 05: loss=0.4266, train_acc=87.59%, test_acc=87.94%, elapsed=1.41min
# Epoch 06: loss=0.4043, train_acc=87.93%, test_acc=88.36%, elapsed=1.64min
# Epoch 07: loss=0.3908, train_acc=88.41%, test_acc=89.13%, elapsed=1.87min
# Epoch 08: loss=0.3761, train_acc=88.89%, test_acc=89.68%, elapsed=2.11min
# Epoch 09: loss=0.3665, train_acc=89.29%, test_acc=90.11%, elapsed=2.34min
# Epoch 10: loss=0.3594, train_acc=89.56%, test_acc=89.74%, elapsed=2.58min
# Epoch 11: loss=0.3456, train_acc=89.73%, test_acc=90.04%, elapsed=2.81min
# Epoch 12: loss=0.3376, train_acc=90.08%, test_acc=90.05%, elapsed=3.04min
# Epoch 13: loss=0.3300, train_acc=90.43%, test_acc=90.23%, elapsed=3.28min
# Epoch 14: loss=0.3232, train_acc=90.51%, test_acc=90.76%, elapsed=3.52min
# Epoch 15: loss=0.3165, train_acc=90.68%, test_acc=90.78%, elapsed=3.75min
# Epoch 16: loss=0.3151, train_acc=90.72%, test_acc=91.04%, elapsed=3.98min
# Epoch 17: loss=0.3055, train_acc=90.97%, test_acc=91.34%, elapsed=4.22min
# Epoch 18: loss=0.3014, train_acc=90.92%, test_acc=90.85%, elapsed=4.46min
# Epoch 19: loss=0.2981, train_acc=91.05%, test_acc=91.42%, elapsed=4.70min
# --> IzhSNN integrator=symplectic: mean=91.42% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=euler seed=0 dt=0.5 ===
# Epoch 00: loss=1.0547, train_acc=68.79%, test_acc=80.13%, elapsed=0.20min
# Epoch 01: loss=0.6271, train_acc=81.45%, test_acc=83.71%, elapsed=0.40min
# Epoch 02: loss=0.5556, train_acc=83.57%, test_acc=84.89%, elapsed=0.60min
# Epoch 03: loss=0.5082, train_acc=85.05%, test_acc=86.54%, elapsed=0.80min
# Epoch 04: loss=0.4669, train_acc=86.44%, test_acc=87.58%, elapsed=1.00min
# Epoch 05: loss=0.4368, train_acc=87.22%, test_acc=88.39%, elapsed=1.20min
# Epoch 06: loss=0.4089, train_acc=87.95%, test_acc=88.82%, elapsed=1.41min
# Epoch 07: loss=0.3903, train_acc=88.58%, test_acc=88.94%, elapsed=1.61min
# Epoch 08: loss=0.3747, train_acc=89.06%, test_acc=89.73%, elapsed=1.81min
# Epoch 09: loss=0.3651, train_acc=89.26%, test_acc=90.39%, elapsed=2.01min
# Epoch 10: loss=0.3502, train_acc=89.76%, test_acc=90.12%, elapsed=2.21min
# Epoch 11: loss=0.3367, train_acc=90.01%, test_acc=90.07%, elapsed=2.41min
# Epoch 12: loss=0.3288, train_acc=90.27%, test_acc=90.27%, elapsed=2.61min
# Epoch 13: loss=0.3171, train_acc=90.62%, test_acc=90.94%, elapsed=2.81min
# Epoch 14: loss=0.3106, train_acc=90.76%, test_acc=90.84%, elapsed=3.01min
# Epoch 15: loss=0.3026, train_acc=91.05%, test_acc=91.24%, elapsed=3.21min
# Epoch 16: loss=0.2981, train_acc=91.13%, test_acc=91.59%, elapsed=3.41min
# Epoch 17: loss=0.2869, train_acc=91.41%, test_acc=91.32%, elapsed=3.61min
# Epoch 18: loss=0.2824, train_acc=91.49%, test_acc=91.49%, elapsed=3.81min
# Epoch 19: loss=0.2811, train_acc=91.64%, test_acc=92.03%, elapsed=4.01min
# --> LIFSNN integrator=euler: mean=92.03% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=exp seed=0 dt=0.5 ===
# Epoch 00: loss=1.0795, train_acc=68.07%, test_acc=80.35%, elapsed=0.20min
# Epoch 01: loss=0.6326, train_acc=81.42%, test_acc=83.52%, elapsed=0.41min
# Epoch 02: loss=0.5617, train_acc=83.39%, test_acc=84.90%, elapsed=0.61min
# Epoch 03: loss=0.5149, train_acc=84.72%, test_acc=85.91%, elapsed=0.82min
# Epoch 04: loss=0.4766, train_acc=86.01%, test_acc=87.54%, elapsed=1.03min
# Epoch 05: loss=0.4432, train_acc=87.05%, test_acc=87.73%, elapsed=1.24min
# Epoch 06: loss=0.4198, train_acc=87.61%, test_acc=88.45%, elapsed=1.44min
# Epoch 07: loss=0.4019, train_acc=88.29%, test_acc=88.96%, elapsed=1.65min
# Epoch 08: loss=0.3866, train_acc=88.73%, test_acc=89.65%, elapsed=1.85min
# Epoch 09: loss=0.3763, train_acc=88.99%, test_acc=90.00%, elapsed=2.06min
# Epoch 10: loss=0.3599, train_acc=89.49%, test_acc=89.88%, elapsed=2.26min
# Epoch 11: loss=0.3465, train_acc=89.88%, test_acc=90.01%, elapsed=2.47min
# Epoch 12: loss=0.3430, train_acc=89.93%, test_acc=90.36%, elapsed=2.67min
# Epoch 13: loss=0.3296, train_acc=90.38%, test_acc=90.42%, elapsed=2.87min
# Epoch 14: loss=0.3249, train_acc=90.43%, test_acc=90.37%, elapsed=3.08min
# Epoch 15: loss=0.3132, train_acc=90.70%, test_acc=91.01%, elapsed=3.28min
# Epoch 16: loss=0.3113, train_acc=90.85%, test_acc=91.12%, elapsed=3.49min
# Epoch 17: loss=0.2999, train_acc=91.06%, test_acc=91.40%, elapsed=3.69min
# Epoch 18: loss=0.2969, train_acc=91.29%, test_acc=91.31%, elapsed=3.89min
# Epoch 19: loss=0.2946, train_acc=91.25%, test_acc=91.90%, elapsed=4.10min
# --> LIFSNN integrator=exp: mean=91.90% std=0.00% over seeds=[0]
#
# All experiments finished. Results saved to results.csv
# {'model': 'IzhSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [91.16], 'mean_acc': 91.16, 'std_acc': 0.0}
# {'model': 'IzhSNN', 'integrator': 'symplectic', 'seeds': [0], 'accs': [91.42], 'mean_acc': 91.42, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [92.03], 'mean_acc': 92.03, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'exp', 'seeds': [0], 'accs': [91.9], 'mean_acc': 91.9, 'std_acc': 0.0}

# %%
if __name__ == "__main__":
    dt=1.0
    encoder.reset(dt=dt)
    results = run_grid_experiments()
    # печать финальной сводки
    for r in results:
        print(r)
# Out:
# === Model IzhSNN integrator=euler seed=0 dt=1.0 ===
# Epoch 00: loss=0.8681, train_acc=77.85%, test_acc=85.57%, elapsed=0.19min
# Epoch 01: loss=0.4520, train_acc=86.99%, test_acc=88.30%, elapsed=0.37min
# Epoch 02: loss=0.3831, train_acc=88.77%, test_acc=90.28%, elapsed=0.56min
# Epoch 03: loss=0.3364, train_acc=89.94%, test_acc=90.64%, elapsed=0.74min
# Epoch 04: loss=0.3051, train_acc=91.01%, test_acc=91.73%, elapsed=0.92min
# Epoch 05: loss=0.2746, train_acc=91.83%, test_acc=92.11%, elapsed=1.11min
# Epoch 06: loss=0.2583, train_acc=92.17%, test_acc=92.87%, elapsed=1.29min
# Epoch 07: loss=0.2476, train_acc=92.51%, test_acc=92.94%, elapsed=1.48min
# Epoch 08: loss=0.2333, train_acc=93.03%, test_acc=93.21%, elapsed=1.67min
# Epoch 09: loss=0.2256, train_acc=93.22%, test_acc=93.43%, elapsed=1.85min
# Epoch 10: loss=0.2174, train_acc=93.36%, test_acc=93.24%, elapsed=2.04min
# Epoch 11: loss=0.2086, train_acc=93.61%, test_acc=93.83%, elapsed=2.22min
# Epoch 12: loss=0.2020, train_acc=93.78%, test_acc=93.62%, elapsed=2.41min
# Epoch 13: loss=0.1964, train_acc=93.80%, test_acc=93.47%, elapsed=2.59min
# Epoch 14: loss=0.1911, train_acc=94.04%, test_acc=93.78%, elapsed=2.77min
# Epoch 15: loss=0.1877, train_acc=94.14%, test_acc=93.78%, elapsed=2.95min
# Epoch 16: loss=0.1832, train_acc=94.20%, test_acc=93.96%, elapsed=3.14min
# Epoch 17: loss=0.1791, train_acc=94.41%, test_acc=94.35%, elapsed=3.32min
# Epoch 18: loss=0.1754, train_acc=94.45%, test_acc=94.44%, elapsed=3.51min
# Epoch 19: loss=0.1729, train_acc=94.61%, test_acc=94.36%, elapsed=3.69min
# --> IzhSNN integrator=euler: mean=94.36% std=0.00% over seeds=[0]
#
# === Model IzhSNN integrator=symplectic seed=0 dt=1.0 ===
# Epoch 00: loss=0.8702, train_acc=77.60%, test_acc=85.71%, elapsed=0.19min
# Epoch 01: loss=0.4447, train_acc=87.11%, test_acc=88.48%, elapsed=0.37min
# Epoch 02: loss=0.3775, train_acc=89.04%, test_acc=90.44%, elapsed=0.56min
# Epoch 03: loss=0.3261, train_acc=90.24%, test_acc=91.00%, elapsed=0.75min
# Epoch 04: loss=0.2960, train_acc=91.23%, test_acc=91.81%, elapsed=0.93min
# Epoch 05: loss=0.2680, train_acc=91.94%, test_acc=92.42%, elapsed=1.12min
# Epoch 06: loss=0.2528, train_acc=92.38%, test_acc=92.97%, elapsed=1.31min
# Epoch 07: loss=0.2381, train_acc=92.80%, test_acc=93.10%, elapsed=1.49min
# Epoch 08: loss=0.2220, train_acc=93.28%, test_acc=93.45%, elapsed=1.68min
# Epoch 09: loss=0.2162, train_acc=93.45%, test_acc=93.32%, elapsed=1.86min
# Epoch 10: loss=0.2065, train_acc=93.70%, test_acc=93.75%, elapsed=2.05min
# Epoch 11: loss=0.1988, train_acc=93.86%, test_acc=93.88%, elapsed=2.23min
# Epoch 12: loss=0.1924, train_acc=94.15%, test_acc=93.82%, elapsed=2.42min
# Epoch 13: loss=0.1864, train_acc=94.24%, test_acc=93.92%, elapsed=2.60min
# Epoch 14: loss=0.1792, train_acc=94.49%, test_acc=93.89%, elapsed=2.78min
# Epoch 15: loss=0.1749, train_acc=94.65%, test_acc=94.40%, elapsed=2.97min
# Epoch 16: loss=0.1741, train_acc=94.49%, test_acc=94.49%, elapsed=3.15min
# Epoch 17: loss=0.1698, train_acc=94.74%, test_acc=94.38%, elapsed=3.34min
# Epoch 18: loss=0.1652, train_acc=94.84%, test_acc=94.59%, elapsed=3.52min
# Epoch 19: loss=0.1613, train_acc=94.88%, test_acc=94.61%, elapsed=3.71min
# --> IzhSNN integrator=symplectic: mean=94.61% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=euler seed=0 dt=1.0 ===
# Epoch 00: loss=0.7679, train_acc=77.50%, test_acc=85.43%, elapsed=0.17min
# Epoch 01: loss=0.4165, train_acc=87.49%, test_acc=89.30%, elapsed=0.34min
# Epoch 02: loss=0.3324, train_acc=89.93%, test_acc=91.54%, elapsed=0.51min
# Epoch 03: loss=0.2782, train_acc=91.63%, test_acc=92.15%, elapsed=0.67min
# Epoch 04: loss=0.2454, train_acc=92.46%, test_acc=93.25%, elapsed=0.84min
# Epoch 05: loss=0.2170, train_acc=93.38%, test_acc=93.77%, elapsed=1.01min
# Epoch 06: loss=0.1997, train_acc=93.79%, test_acc=94.53%, elapsed=1.18min
# Epoch 07: loss=0.1850, train_acc=94.33%, test_acc=94.26%, elapsed=1.35min
# Epoch 08: loss=0.1733, train_acc=94.68%, test_acc=95.06%, elapsed=1.52min
# Epoch 09: loss=0.1638, train_acc=94.94%, test_acc=94.88%, elapsed=1.69min
# Epoch 10: loss=0.1544, train_acc=95.17%, test_acc=94.72%, elapsed=1.85min
# Epoch 11: loss=0.1468, train_acc=95.44%, test_acc=95.45%, elapsed=2.02min
# Epoch 12: loss=0.1407, train_acc=95.56%, test_acc=95.05%, elapsed=2.19min
# Epoch 13: loss=0.1377, train_acc=95.60%, test_acc=95.46%, elapsed=2.36min
# Epoch 14: loss=0.1289, train_acc=95.90%, test_acc=95.62%, elapsed=2.53min
# Epoch 15: loss=0.1247, train_acc=96.02%, test_acc=95.46%, elapsed=2.70min
# Epoch 16: loss=0.1213, train_acc=96.26%, test_acc=95.74%, elapsed=2.87min
# Epoch 17: loss=0.1166, train_acc=96.22%, test_acc=96.01%, elapsed=3.03min
# Epoch 18: loss=0.1144, train_acc=96.41%, test_acc=95.65%, elapsed=3.20min
# Epoch 19: loss=0.1104, train_acc=96.45%, test_acc=96.14%, elapsed=3.37min
# --> LIFSNN integrator=euler: mean=96.14% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=exp seed=0 dt=1.0 ===
# Epoch 00: loss=0.8612, train_acc=75.44%, test_acc=84.47%, elapsed=0.17min
# Epoch 01: loss=0.4600, train_acc=86.21%, test_acc=87.82%, elapsed=0.34min
# Epoch 02: loss=0.3778, train_acc=88.76%, test_acc=90.36%, elapsed=0.51min
# Epoch 03: loss=0.3222, train_acc=90.29%, test_acc=91.45%, elapsed=0.68min
# Epoch 04: loss=0.2840, train_acc=91.46%, test_acc=92.22%, elapsed=0.84min
# Epoch 05: loss=0.2539, train_acc=92.26%, test_acc=92.65%, elapsed=1.01min
# Epoch 06: loss=0.2330, train_acc=92.76%, test_acc=93.81%, elapsed=1.18min
# Epoch 07: loss=0.2165, train_acc=93.40%, test_acc=93.61%, elapsed=1.35min
# Epoch 08: loss=0.2033, train_acc=93.72%, test_acc=94.14%, elapsed=1.52min
# Epoch 09: loss=0.1923, train_acc=94.13%, test_acc=94.08%, elapsed=1.69min
# Epoch 10: loss=0.1809, train_acc=94.52%, test_acc=94.25%, elapsed=1.86min
# Epoch 11: loss=0.1724, train_acc=94.75%, test_acc=94.90%, elapsed=2.02min
# Epoch 12: loss=0.1622, train_acc=95.04%, test_acc=94.73%, elapsed=2.19min
# Epoch 13: loss=0.1597, train_acc=95.01%, test_acc=94.84%, elapsed=2.35min
# Epoch 14: loss=0.1513, train_acc=95.22%, test_acc=95.03%, elapsed=2.52min
# Epoch 15: loss=0.1451, train_acc=95.45%, test_acc=95.11%, elapsed=2.69min
# Epoch 16: loss=0.1420, train_acc=95.54%, test_acc=95.19%, elapsed=2.86min
# Epoch 17: loss=0.1371, train_acc=95.64%, test_acc=95.47%, elapsed=3.03min
# Epoch 18: loss=0.1350, train_acc=95.69%, test_acc=95.31%, elapsed=3.19min
# Epoch 19: loss=0.1297, train_acc=95.90%, test_acc=95.87%, elapsed=3.36min
# --> LIFSNN integrator=exp: mean=95.87% std=0.00% over seeds=[0]
#
# All experiments finished. Results saved to results.csv
# {'model': 'IzhSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [94.36], 'mean_acc': 94.36, 'std_acc': 0.0}
# {'model': 'IzhSNN', 'integrator': 'symplectic', 'seeds': [0], 'accs': [94.61], 'mean_acc': 94.61, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [96.14], 'mean_acc': 96.14, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'exp', 'seeds': [0], 'accs': [95.87], 'mean_acc': 95.87, 'std_acc': 0.0}

# %%
if __name__ == "__main__":
    dt=2.0
    encoder.reset(dt=dt)
    results = run_grid_experiments()
    # печать финальной сводки
    for r in results:
        print(r)
# Out:
# === Model IzhSNN integrator=euler seed=0 dt=2.0 ===
# Epoch 00: loss=0.4597, train_acc=87.48%, test_acc=92.26%, elapsed=0.16min
# Epoch 01: loss=0.2232, train_acc=93.35%, test_acc=93.96%, elapsed=0.31min
# Epoch 02: loss=0.1732, train_acc=94.77%, test_acc=94.89%, elapsed=0.47min
# Epoch 03: loss=0.1430, train_acc=95.71%, test_acc=95.75%, elapsed=0.64min
# Epoch 04: loss=0.1284, train_acc=96.02%, test_acc=96.05%, elapsed=0.80min
# Epoch 05: loss=0.1162, train_acc=96.36%, test_acc=95.99%, elapsed=0.95min
# Epoch 06: loss=0.1056, train_acc=96.66%, test_acc=96.36%, elapsed=1.11min
# Epoch 07: loss=0.0991, train_acc=96.84%, test_acc=96.21%, elapsed=1.27min
# Epoch 08: loss=0.0929, train_acc=97.08%, test_acc=96.67%, elapsed=1.43min
# Epoch 09: loss=0.0903, train_acc=97.11%, test_acc=96.62%, elapsed=1.60min
# Epoch 10: loss=0.0833, train_acc=97.29%, test_acc=96.49%, elapsed=1.75min
# Epoch 11: loss=0.0810, train_acc=97.39%, test_acc=96.69%, elapsed=1.91min
# Epoch 12: loss=0.0783, train_acc=97.49%, test_acc=96.71%, elapsed=2.07min
# Epoch 13: loss=0.0760, train_acc=97.54%, test_acc=96.76%, elapsed=2.23min
# Epoch 14: loss=0.0739, train_acc=97.62%, test_acc=96.79%, elapsed=2.39min
# Epoch 15: loss=0.0708, train_acc=97.70%, test_acc=96.61%, elapsed=2.54min
# Epoch 16: loss=0.0679, train_acc=97.80%, test_acc=96.84%, elapsed=2.70min
# Epoch 17: loss=0.0674, train_acc=97.87%, test_acc=96.67%, elapsed=2.86min
# Epoch 18: loss=0.0663, train_acc=97.77%, test_acc=96.86%, elapsed=3.02min
# Epoch 19: loss=0.0648, train_acc=97.85%, test_acc=96.71%, elapsed=3.18min
# --> IzhSNN integrator=euler: mean=96.71% std=0.00% over seeds=[0]
#
# === Model IzhSNN integrator=symplectic seed=0 dt=2.0 ===
# Epoch 00: loss=0.4044, train_acc=88.78%, test_acc=93.27%, elapsed=0.16min
# Epoch 01: loss=0.1873, train_acc=94.43%, test_acc=94.83%, elapsed=0.32min
# Epoch 02: loss=0.1435, train_acc=95.77%, test_acc=95.52%, elapsed=0.49min
# Epoch 03: loss=0.1176, train_acc=96.44%, test_acc=96.17%, elapsed=0.65min
# Epoch 04: loss=0.1065, train_acc=96.73%, test_acc=96.29%, elapsed=0.80min
# Epoch 05: loss=0.0975, train_acc=96.95%, test_acc=96.10%, elapsed=0.96min
# Epoch 06: loss=0.0899, train_acc=97.14%, test_acc=96.88%, elapsed=1.13min
# Epoch 07: loss=0.0846, train_acc=97.29%, test_acc=96.49%, elapsed=1.29min
# Epoch 08: loss=0.0776, train_acc=97.46%, test_acc=96.76%, elapsed=1.45min
# Epoch 09: loss=0.0758, train_acc=97.54%, test_acc=96.79%, elapsed=1.60min
# Epoch 10: loss=0.0699, train_acc=97.74%, test_acc=96.59%, elapsed=1.77min
# Epoch 11: loss=0.0681, train_acc=97.77%, test_acc=96.48%, elapsed=1.93min
# Epoch 12: loss=0.0677, train_acc=97.78%, test_acc=96.87%, elapsed=2.09min
# Epoch 13: loss=0.0625, train_acc=97.98%, test_acc=96.94%, elapsed=2.25min
# Epoch 14: loss=0.0618, train_acc=97.95%, test_acc=97.02%, elapsed=2.40min
# Epoch 15: loss=0.0595, train_acc=98.04%, test_acc=96.77%, elapsed=2.56min
# Epoch 16: loss=0.0602, train_acc=98.00%, test_acc=96.99%, elapsed=2.72min
# Epoch 17: loss=0.0553, train_acc=98.21%, test_acc=96.89%, elapsed=2.89min
# Epoch 18: loss=0.0557, train_acc=98.16%, test_acc=97.24%, elapsed=3.04min
# Epoch 19: loss=0.0538, train_acc=98.19%, test_acc=96.64%, elapsed=3.20min
# --> IzhSNN integrator=symplectic: mean=96.64% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=euler seed=0 dt=2.0 ===
# Epoch 00: loss=0.4311, train_acc=87.27%, test_acc=92.60%, elapsed=0.16min
# Epoch 01: loss=0.2027, train_acc=93.94%, test_acc=94.42%, elapsed=0.32min
# Epoch 02: loss=0.1560, train_acc=95.36%, test_acc=95.58%, elapsed=0.47min
# Epoch 03: loss=0.1278, train_acc=96.05%, test_acc=96.07%, elapsed=0.62min
# Epoch 04: loss=0.1121, train_acc=96.57%, test_acc=96.23%, elapsed=0.77min
# Epoch 05: loss=0.1008, train_acc=96.88%, test_acc=96.25%, elapsed=0.93min
# Epoch 06: loss=0.0889, train_acc=97.25%, test_acc=96.95%, elapsed=1.08min
# Epoch 07: loss=0.0846, train_acc=97.38%, test_acc=96.62%, elapsed=1.23min
# Epoch 08: loss=0.0770, train_acc=97.62%, test_acc=96.63%, elapsed=1.38min
# Epoch 09: loss=0.0718, train_acc=97.72%, test_acc=96.97%, elapsed=1.54min
# Epoch 10: loss=0.0669, train_acc=97.88%, test_acc=96.67%, elapsed=1.69min
# Epoch 11: loss=0.0641, train_acc=97.94%, test_acc=96.88%, elapsed=1.83min
# Epoch 12: loss=0.0617, train_acc=98.07%, test_acc=97.01%, elapsed=1.99min
# Epoch 13: loss=0.0564, train_acc=98.17%, test_acc=97.19%, elapsed=2.15min
# Epoch 14: loss=0.0561, train_acc=98.19%, test_acc=97.14%, elapsed=2.30min
# Epoch 15: loss=0.0544, train_acc=98.23%, test_acc=96.86%, elapsed=2.45min
# Epoch 16: loss=0.0512, train_acc=98.36%, test_acc=97.02%, elapsed=2.60min
# Epoch 17: loss=0.0499, train_acc=98.39%, test_acc=96.68%, elapsed=2.76min
# Epoch 18: loss=0.0496, train_acc=98.36%, test_acc=97.00%, elapsed=2.92min
# Epoch 19: loss=0.0471, train_acc=98.45%, test_acc=96.99%, elapsed=3.06min
# --> LIFSNN integrator=euler: mean=96.99% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=exp seed=0 dt=2.0 ===
# Epoch 00: loss=0.4753, train_acc=85.84%, test_acc=91.49%, elapsed=0.15min
# Epoch 01: loss=0.2385, train_acc=92.85%, test_acc=93.70%, elapsed=0.31min
# Epoch 02: loss=0.1847, train_acc=94.39%, test_acc=94.68%, elapsed=0.47min
# Epoch 03: loss=0.1519, train_acc=95.39%, test_acc=95.44%, elapsed=0.62min
# Epoch 04: loss=0.1321, train_acc=96.02%, test_acc=95.83%, elapsed=0.77min
# Epoch 05: loss=0.1179, train_acc=96.32%, test_acc=96.02%, elapsed=0.92min
# Epoch 06: loss=0.1054, train_acc=96.73%, test_acc=96.49%, elapsed=1.08min
# Epoch 07: loss=0.0985, train_acc=96.96%, test_acc=96.57%, elapsed=1.24min
# Epoch 08: loss=0.0891, train_acc=97.30%, test_acc=96.56%, elapsed=1.38min
# Epoch 09: loss=0.0822, train_acc=97.42%, test_acc=96.85%, elapsed=1.54min
# Epoch 10: loss=0.0788, train_acc=97.53%, test_acc=96.66%, elapsed=1.70min
# Epoch 11: loss=0.0724, train_acc=97.68%, test_acc=96.79%, elapsed=1.85min
# Epoch 12: loss=0.0705, train_acc=97.73%, test_acc=96.81%, elapsed=2.00min
# Epoch 13: loss=0.0638, train_acc=98.00%, test_acc=96.93%, elapsed=2.16min
# Epoch 14: loss=0.0640, train_acc=97.92%, test_acc=97.16%, elapsed=2.31min
# Epoch 15: loss=0.0607, train_acc=98.05%, test_acc=96.75%, elapsed=2.47min
# Epoch 16: loss=0.0580, train_acc=98.07%, test_acc=97.16%, elapsed=2.62min
# Epoch 17: loss=0.0563, train_acc=98.21%, test_acc=96.69%, elapsed=2.78min
# Epoch 18: loss=0.0542, train_acc=98.18%, test_acc=97.25%, elapsed=2.93min
# Epoch 19: loss=0.0513, train_acc=98.35%, test_acc=97.06%, elapsed=3.09min
# --> LIFSNN integrator=exp: mean=97.06% std=0.00% over seeds=[0]
#
# All experiments finished. Results saved to results.csv
# {'model': 'IzhSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [96.71], 'mean_acc': 96.71, 'std_acc': 0.0}
# {'model': 'IzhSNN', 'integrator': 'symplectic', 'seeds': [0], 'accs': [96.64], 'mean_acc': 96.64, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [96.99], 'mean_acc': 96.99, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'exp', 'seeds': [0], 'accs': [97.06], 'mean_acc': 97.06, 'std_acc': 0.0}

# %%
if __name__ == "__main__":
    dt=5.0
    encoder.reset(dt=dt)
    results = run_grid_experiments()
    # печать финальной сводки
    for r in results:
        print(r)
# Out:
# === Model IzhSNN integrator=euler seed=0 dt=5.0 ===
# Epoch 00: loss=0.3494, train_acc=90.63%, test_acc=94.47%, elapsed=0.16min
# Epoch 01: loss=0.1640, train_acc=95.26%, test_acc=95.58%, elapsed=0.31min
# Epoch 02: loss=0.1254, train_acc=96.35%, test_acc=96.13%, elapsed=0.48min
# Epoch 03: loss=0.1010, train_acc=97.05%, test_acc=96.50%, elapsed=0.62min
# Epoch 04: loss=0.0866, train_acc=97.43%, test_acc=96.72%, elapsed=0.77min
# Epoch 05: loss=0.0769, train_acc=97.74%, test_acc=97.01%, elapsed=0.93min
# Epoch 06: loss=0.0661, train_acc=98.07%, test_acc=96.65%, elapsed=1.08min
# Epoch 07: loss=0.0632, train_acc=98.14%, test_acc=97.08%, elapsed=1.23min
# Epoch 08: loss=0.0561, train_acc=98.33%, test_acc=97.13%, elapsed=1.37min
# Epoch 09: loss=0.0516, train_acc=98.44%, test_acc=97.22%, elapsed=1.53min
# Epoch 10: loss=0.0486, train_acc=98.48%, test_acc=97.20%, elapsed=1.68min
# Epoch 11: loss=0.0457, train_acc=98.62%, test_acc=97.03%, elapsed=1.82min
# Epoch 12: loss=0.0420, train_acc=98.72%, test_acc=97.25%, elapsed=1.97min
# Epoch 13: loss=0.0407, train_acc=98.76%, test_acc=97.52%, elapsed=2.12min
# Epoch 14: loss=0.0389, train_acc=98.80%, test_acc=97.25%, elapsed=2.27min
# Epoch 15: loss=0.0356, train_acc=98.93%, test_acc=97.27%, elapsed=2.41min
# Epoch 16: loss=0.0346, train_acc=98.98%, test_acc=96.99%, elapsed=2.56min
# Epoch 17: loss=0.0343, train_acc=98.93%, test_acc=96.88%, elapsed=2.72min
# Epoch 18: loss=0.0340, train_acc=98.91%, test_acc=97.22%, elapsed=2.87min
# Epoch 19: loss=0.0315, train_acc=99.04%, test_acc=97.14%, elapsed=3.01min
# --> IzhSNN integrator=euler: mean=97.14% std=0.00% over seeds=[0]
#
# === Model IzhSNN integrator=symplectic seed=0 dt=5.0 ===
# Epoch 00: loss=0.3495, train_acc=90.64%, test_acc=94.47%, elapsed=0.15min
# Epoch 01: loss=0.1630, train_acc=95.25%, test_acc=95.65%, elapsed=0.30min
# Epoch 02: loss=0.1234, train_acc=96.39%, test_acc=96.28%, elapsed=0.45min
# Epoch 03: loss=0.1010, train_acc=97.05%, test_acc=96.42%, elapsed=0.59min
# Epoch 04: loss=0.0864, train_acc=97.47%, test_acc=96.90%, elapsed=0.75min
# Epoch 05: loss=0.0757, train_acc=97.80%, test_acc=97.01%, elapsed=0.90min
# Epoch 06: loss=0.0670, train_acc=98.01%, test_acc=96.86%, elapsed=1.04min
# Epoch 07: loss=0.0611, train_acc=98.18%, test_acc=96.95%, elapsed=1.19min
# Epoch 08: loss=0.0561, train_acc=98.29%, test_acc=97.01%, elapsed=1.34min
# Epoch 09: loss=0.0511, train_acc=98.44%, test_acc=97.20%, elapsed=1.49min
# Epoch 10: loss=0.0464, train_acc=98.60%, test_acc=97.03%, elapsed=1.63min
# Epoch 11: loss=0.0447, train_acc=98.68%, test_acc=97.12%, elapsed=1.78min
# Epoch 12: loss=0.0435, train_acc=98.68%, test_acc=97.25%, elapsed=1.93min
# Epoch 13: loss=0.0407, train_acc=98.78%, test_acc=97.41%, elapsed=2.09min
# Epoch 14: loss=0.0375, train_acc=98.89%, test_acc=97.21%, elapsed=2.23min
# Epoch 15: loss=0.0365, train_acc=98.87%, test_acc=96.78%, elapsed=2.38min
# Epoch 16: loss=0.0370, train_acc=98.81%, test_acc=97.22%, elapsed=2.53min
# Epoch 17: loss=0.0355, train_acc=98.92%, test_acc=96.84%, elapsed=2.67min
# Epoch 18: loss=0.0332, train_acc=98.98%, test_acc=97.22%, elapsed=2.82min
# Epoch 19: loss=0.0306, train_acc=99.03%, test_acc=97.27%, elapsed=2.97min
# --> IzhSNN integrator=symplectic: mean=97.27% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=euler seed=0 dt=5.0 ===
# Epoch 00: loss=0.3422, train_acc=90.74%, test_acc=94.47%, elapsed=0.15min
# Epoch 01: loss=0.1627, train_acc=95.30%, test_acc=95.58%, elapsed=0.29min
# Epoch 02: loss=0.1237, train_acc=96.42%, test_acc=96.08%, elapsed=0.43min
# Epoch 03: loss=0.1011, train_acc=97.04%, test_acc=96.54%, elapsed=0.58min
# Epoch 04: loss=0.0845, train_acc=97.51%, test_acc=96.76%, elapsed=0.73min
# Epoch 05: loss=0.0756, train_acc=97.80%, test_acc=97.04%, elapsed=0.87min
# Epoch 06: loss=0.0674, train_acc=97.99%, test_acc=96.79%, elapsed=1.02min
# Epoch 07: loss=0.0621, train_acc=98.19%, test_acc=96.70%, elapsed=1.17min
# Epoch 08: loss=0.0568, train_acc=98.32%, test_acc=97.28%, elapsed=1.31min
# Epoch 09: loss=0.0524, train_acc=98.42%, test_acc=97.15%, elapsed=1.45min
# Epoch 10: loss=0.0488, train_acc=98.58%, test_acc=97.02%, elapsed=1.60min
# Epoch 11: loss=0.0459, train_acc=98.58%, test_acc=97.16%, elapsed=1.75min
# Epoch 12: loss=0.0435, train_acc=98.69%, test_acc=97.34%, elapsed=1.89min
# Epoch 13: loss=0.0391, train_acc=98.85%, test_acc=97.29%, elapsed=2.04min
# Epoch 14: loss=0.0372, train_acc=98.89%, test_acc=97.28%, elapsed=2.19min
# Epoch 15: loss=0.0346, train_acc=98.96%, test_acc=97.24%, elapsed=2.33min
# Epoch 16: loss=0.0335, train_acc=98.96%, test_acc=97.16%, elapsed=2.47min
# Epoch 17: loss=0.0334, train_acc=98.96%, test_acc=97.10%, elapsed=2.62min
# Epoch 18: loss=0.0328, train_acc=99.00%, test_acc=97.17%, elapsed=2.77min
# Epoch 19: loss=0.0323, train_acc=98.98%, test_acc=97.37%, elapsed=2.91min
# --> LIFSNN integrator=euler: mean=97.37% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=exp seed=0 dt=5.0 ===
# Epoch 00: loss=0.3821, train_acc=88.94%, test_acc=94.13%, elapsed=0.15min
# Epoch 01: loss=0.1684, train_acc=95.02%, test_acc=95.56%, elapsed=0.30min
# Epoch 02: loss=0.1236, train_acc=96.41%, test_acc=96.44%, elapsed=0.44min
# Epoch 03: loss=0.0987, train_acc=97.09%, test_acc=96.73%, elapsed=0.58min
# Epoch 04: loss=0.0811, train_acc=97.56%, test_acc=97.02%, elapsed=0.74min
# Epoch 05: loss=0.0692, train_acc=97.99%, test_acc=97.11%, elapsed=0.88min
# Epoch 06: loss=0.0599, train_acc=98.23%, test_acc=97.21%, elapsed=1.02min
# Epoch 07: loss=0.0521, train_acc=98.49%, test_acc=97.07%, elapsed=1.17min
# Epoch 08: loss=0.0451, train_acc=98.68%, test_acc=97.47%, elapsed=1.32min
# Epoch 09: loss=0.0396, train_acc=98.88%, test_acc=97.22%, elapsed=1.47min
# Epoch 10: loss=0.0372, train_acc=98.91%, test_acc=97.18%, elapsed=1.61min
# Epoch 11: loss=0.0341, train_acc=99.00%, test_acc=97.29%, elapsed=1.76min
# Epoch 12: loss=0.0307, train_acc=99.12%, test_acc=97.43%, elapsed=1.91min
# Epoch 13: loss=0.0285, train_acc=99.16%, test_acc=97.56%, elapsed=2.05min
# Epoch 14: loss=0.0254, train_acc=99.32%, test_acc=97.78%, elapsed=2.19min
# Epoch 15: loss=0.0231, train_acc=99.34%, test_acc=97.42%, elapsed=2.34min
# Epoch 16: loss=0.0233, train_acc=99.34%, test_acc=97.43%, elapsed=2.49min
# Epoch 17: loss=0.0209, train_acc=99.41%, test_acc=97.37%, elapsed=2.63min
# Epoch 18: loss=0.0199, train_acc=99.41%, test_acc=97.34%, elapsed=2.78min
# Epoch 19: loss=0.0197, train_acc=99.45%, test_acc=97.38%, elapsed=2.93min
# --> LIFSNN integrator=exp: mean=97.38% std=0.00% over seeds=[0]
#
# All experiments finished. Results saved to results.csv
# {'model': 'IzhSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [97.14], 'mean_acc': 97.14, 'std_acc': 0.0}
# {'model': 'IzhSNN', 'integrator': 'symplectic', 'seeds': [0], 'accs': [97.27], 'mean_acc': 97.27, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [97.37], 'mean_acc': 97.37, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'exp', 'seeds': [0], 'accs': [97.38], 'mean_acc': 97.38, 'std_acc': 0.0}

# %% [markdown]
# # 11. Эксперименты с фиксированным T

# %%
if __name__ == "__main__":
    dt=0.05
    encoder.reset(dt=dt)
    results = run_grid_experiments(SEEDS, dt, T, EPOCHS=10)
    # печать финальной сводки
    for r in results:
        print(r)
# Out:
# === Model IzhSNN integrator=euler seed=0 dt=0.05 ===
# Epoch 00: loss=2.2431, train_acc=16.29%, test_acc=29.22%, elapsed=0.99min
# Epoch 01: loss=1.8953, train_acc=33.75%, test_acc=37.43%, elapsed=1.79min
# Epoch 02: loss=1.6694, train_acc=40.35%, test_acc=43.37%, elapsed=2.55min
# Epoch 03: loss=1.5743, train_acc=43.94%, test_acc=45.74%, elapsed=3.33min
# Epoch 04: loss=1.5166, train_acc=46.72%, test_acc=48.00%, elapsed=4.08min
# Epoch 05: loss=1.4874, train_acc=48.06%, test_acc=48.33%, elapsed=4.84min
# Epoch 06: loss=1.4686, train_acc=49.04%, test_acc=50.39%, elapsed=5.60min
# Epoch 07: loss=1.4464, train_acc=49.77%, test_acc=50.66%, elapsed=6.36min
# Epoch 08: loss=1.4350, train_acc=50.72%, test_acc=51.29%, elapsed=7.12min
# Epoch 09: loss=1.4178, train_acc=51.69%, test_acc=52.39%, elapsed=7.88min
# --> IzhSNN integrator=euler: mean=52.39% std=0.00% over seeds=[0]
#
# === Model IzhSNN integrator=symplectic seed=0 dt=0.05 ===
# Epoch 00: loss=2.2437, train_acc=16.21%, test_acc=29.21%, elapsed=0.77min
# Epoch 01: loss=1.8930, train_acc=34.05%, test_acc=38.23%, elapsed=1.52min
# Epoch 02: loss=1.6678, train_acc=40.76%, test_acc=43.46%, elapsed=2.29min
# Epoch 03: loss=1.5665, train_acc=44.59%, test_acc=46.25%, elapsed=3.05min
# Epoch 04: loss=1.5139, train_acc=46.75%, test_acc=48.20%, elapsed=3.81min
# Epoch 05: loss=1.4829, train_acc=48.16%, test_acc=50.21%, elapsed=4.57min
# Epoch 06: loss=1.4648, train_acc=49.27%, test_acc=50.92%, elapsed=5.34min
# Epoch 07: loss=1.4454, train_acc=50.19%, test_acc=51.02%, elapsed=6.11min
# Epoch 08: loss=1.4255, train_acc=50.97%, test_acc=52.23%, elapsed=6.88min
# Epoch 09: loss=1.4142, train_acc=51.94%, test_acc=53.73%, elapsed=7.65min
# --> IzhSNN integrator=symplectic: mean=53.73% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=euler seed=0 dt=0.05 ===
# Epoch 00: loss=2.2987, train_acc=10.25%, test_acc=12.75%, elapsed=0.57min
# Epoch 01: loss=2.1215, train_acc=21.08%, test_acc=29.64%, elapsed=1.13min
# Epoch 02: loss=1.7964, train_acc=34.16%, test_acc=39.25%, elapsed=1.68min
# Epoch 03: loss=1.6466, train_acc=39.58%, test_acc=42.16%, elapsed=2.24min
# Epoch 04: loss=1.5598, train_acc=43.34%, test_acc=45.09%, elapsed=2.80min
# Epoch 05: loss=1.5205, train_acc=44.97%, test_acc=47.13%, elapsed=3.36min
# Epoch 06: loss=1.4919, train_acc=46.70%, test_acc=48.49%, elapsed=3.92min
# Epoch 07: loss=1.4663, train_acc=48.00%, test_acc=48.96%, elapsed=4.47min
# Epoch 08: loss=1.4420, train_acc=49.07%, test_acc=50.00%, elapsed=5.03min
# Epoch 09: loss=1.4335, train_acc=49.54%, test_acc=50.95%, elapsed=5.59min
# --> LIFSNN integrator=euler: mean=50.95% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=exp seed=0 dt=0.05 ===
# Epoch 00: loss=2.2989, train_acc=10.24%, test_acc=13.02%, elapsed=0.56min
# Epoch 01: loss=2.1245, train_acc=21.13%, test_acc=29.48%, elapsed=1.11min
# Epoch 02: loss=1.8057, train_acc=33.92%, test_acc=38.63%, elapsed=1.68min
# Epoch 03: loss=1.6444, train_acc=39.66%, test_acc=42.22%, elapsed=2.24min
# Epoch 04: loss=1.5590, train_acc=43.33%, test_acc=45.07%, elapsed=2.79min
# Epoch 05: loss=1.5212, train_acc=45.06%, test_acc=46.91%, elapsed=3.35min
# Epoch 06: loss=1.4902, train_acc=46.87%, test_acc=47.87%, elapsed=3.90min
# Epoch 07: loss=1.4641, train_acc=48.04%, test_acc=49.19%, elapsed=4.46min
# Epoch 08: loss=1.4424, train_acc=49.08%, test_acc=50.12%, elapsed=5.02min
# Epoch 09: loss=1.4294, train_acc=49.62%, test_acc=50.38%, elapsed=5.58min
# --> LIFSNN integrator=exp: mean=50.38% std=0.00% over seeds=[0]
#
# All experiments finished. Results saved to results.csv
# {'model': 'IzhSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [52.39], 'mean_acc': 52.39, 'std_acc': 0.0}
# {'model': 'IzhSNN', 'integrator': 'symplectic', 'seeds': [0], 'accs': [53.73], 'mean_acc': 53.73, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [50.95], 'mean_acc': 50.95, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'exp', 'seeds': [0], 'accs': [50.38], 'mean_acc': 50.38, 'std_acc': 0.0}

# %%
if __name__ == "__main__":
    dt=0.1
    encoder.reset(dt=dt)
    results = run_grid_experiments(SEEDS, dt, T, EPOCHS=10)
    # печать финальной сводки
    for r in results:
        print(r)
# Out:
# === Model IzhSNN integrator=euler seed=0 dt=0.1 ===
# Epoch 00: loss=1.9815, train_acc=35.13%, test_acc=49.66%, elapsed=0.74min
# Epoch 01: loss=1.4290, train_acc=53.52%, test_acc=57.05%, elapsed=1.50min
# Epoch 02: loss=1.2824, train_acc=57.93%, test_acc=60.48%, elapsed=2.25min
# Epoch 03: loss=1.2124, train_acc=60.11%, test_acc=61.31%, elapsed=2.99min
# Epoch 04: loss=1.1756, train_acc=61.69%, test_acc=63.07%, elapsed=3.74min
# Epoch 05: loss=1.1467, train_acc=63.19%, test_acc=63.92%, elapsed=4.49min
# Epoch 06: loss=1.1258, train_acc=63.94%, test_acc=64.95%, elapsed=5.24min
# Epoch 07: loss=1.1052, train_acc=64.66%, test_acc=65.60%, elapsed=5.99min
# Epoch 08: loss=1.0883, train_acc=65.24%, test_acc=66.42%, elapsed=6.74min
# Epoch 09: loss=1.0659, train_acc=66.05%, test_acc=66.65%, elapsed=7.50min
# --> IzhSNN integrator=euler: mean=66.65% std=0.00% over seeds=[0]
#
# === Model IzhSNN integrator=symplectic seed=0 dt=0.1 ===
# Epoch 00: loss=1.9804, train_acc=35.03%, test_acc=49.47%, elapsed=0.75min
# Epoch 01: loss=1.4263, train_acc=53.84%, test_acc=56.96%, elapsed=1.50min
# Epoch 02: loss=1.2779, train_acc=58.10%, test_acc=60.40%, elapsed=2.25min
# Epoch 03: loss=1.2102, train_acc=60.38%, test_acc=61.20%, elapsed=3.00min
# Epoch 04: loss=1.1698, train_acc=61.84%, test_acc=62.63%, elapsed=3.75min
# Epoch 05: loss=1.1384, train_acc=63.15%, test_acc=64.09%, elapsed=4.50min
# Epoch 06: loss=1.1196, train_acc=64.00%, test_acc=64.82%, elapsed=5.25min
# Epoch 07: loss=1.0958, train_acc=64.84%, test_acc=65.66%, elapsed=6.00min
# Epoch 08: loss=1.0826, train_acc=65.35%, test_acc=66.58%, elapsed=6.75min
# Epoch 09: loss=1.0599, train_acc=66.38%, test_acc=67.46%, elapsed=7.50min
# --> IzhSNN integrator=symplectic: mean=67.46% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=euler seed=0 dt=0.1 ===
# Epoch 00: loss=2.1266, train_acc=21.90%, test_acc=43.39%, elapsed=0.55min
# Epoch 01: loss=1.4714, train_acc=50.53%, test_acc=55.06%, elapsed=1.10min
# Epoch 02: loss=1.2970, train_acc=56.69%, test_acc=59.16%, elapsed=1.64min
# Epoch 03: loss=1.2203, train_acc=59.32%, test_acc=60.80%, elapsed=2.18min
# Epoch 04: loss=1.1795, train_acc=60.90%, test_acc=62.34%, elapsed=2.72min
# Epoch 05: loss=1.1461, train_acc=62.62%, test_acc=63.87%, elapsed=3.26min
# Epoch 06: loss=1.1251, train_acc=63.36%, test_acc=64.59%, elapsed=3.80min
# Epoch 07: loss=1.0933, train_acc=64.46%, test_acc=65.70%, elapsed=4.35min
# Epoch 08: loss=1.0756, train_acc=65.52%, test_acc=66.28%, elapsed=4.88min
# Epoch 09: loss=1.0576, train_acc=66.04%, test_acc=66.76%, elapsed=5.43min
# --> LIFSNN integrator=euler: mean=66.76% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=exp seed=0 dt=0.1 ===
# Epoch 00: loss=2.1310, train_acc=21.71%, test_acc=42.45%, elapsed=0.55min
# Epoch 01: loss=1.4738, train_acc=50.51%, test_acc=55.12%, elapsed=1.10min
# Epoch 02: loss=1.2965, train_acc=56.50%, test_acc=58.44%, elapsed=1.63min
# Epoch 03: loss=1.2172, train_acc=59.40%, test_acc=60.63%, elapsed=2.18min
# Epoch 04: loss=1.1781, train_acc=61.08%, test_acc=62.34%, elapsed=2.74min
# Epoch 05: loss=1.1442, train_acc=62.60%, test_acc=63.87%, elapsed=3.29min
# Epoch 06: loss=1.1185, train_acc=63.70%, test_acc=64.09%, elapsed=3.83min
# Epoch 07: loss=1.0984, train_acc=64.45%, test_acc=65.29%, elapsed=4.38min
# Epoch 08: loss=1.0781, train_acc=65.28%, test_acc=66.30%, elapsed=4.93min
# Epoch 09: loss=1.0554, train_acc=66.27%, test_acc=66.67%, elapsed=5.48min
# --> LIFSNN integrator=exp: mean=66.67% std=0.00% over seeds=[0]
#
# All experiments finished. Results saved to results.csv
# {'model': 'IzhSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [66.65], 'mean_acc': 66.65, 'std_acc': 0.0}
# {'model': 'IzhSNN', 'integrator': 'symplectic', 'seeds': [0], 'accs': [67.46], 'mean_acc': 67.46, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [66.76], 'mean_acc': 66.76, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'exp', 'seeds': [0], 'accs': [66.67], 'mean_acc': 66.67, 'std_acc': 0.0}

# %%
if __name__ == "__main__":
    dt=0.5
    encoder.reset(dt=dt)
    results = run_grid_experiments(SEEDS, dt, T, EPOCHS=10)
    # печать финальной сводки
    for r in results:
        print(r)
# Out:
# === Model IzhSNN integrator=euler seed=0 dt=0.5 ===
# Epoch 00: loss=1.0604, train_acc=71.06%, test_acc=81.31%, elapsed=0.76min
# Epoch 01: loss=0.5971, train_acc=82.21%, test_acc=84.12%, elapsed=1.51min
# Epoch 02: loss=0.5275, train_acc=84.36%, test_acc=85.73%, elapsed=2.26min
# Epoch 03: loss=0.4867, train_acc=85.44%, test_acc=86.15%, elapsed=3.00min
# Epoch 04: loss=0.4609, train_acc=86.43%, test_acc=87.52%, elapsed=3.75min
# Epoch 05: loss=0.4348, train_acc=87.24%, test_acc=88.07%, elapsed=4.49min
# Epoch 06: loss=0.4141, train_acc=87.89%, test_acc=88.32%, elapsed=5.23min
# Epoch 07: loss=0.3984, train_acc=88.17%, test_acc=88.84%, elapsed=5.98min
# Epoch 08: loss=0.3849, train_acc=88.71%, test_acc=88.98%, elapsed=6.72min
# Epoch 09: loss=0.3734, train_acc=89.05%, test_acc=89.43%, elapsed=7.47min
# --> IzhSNN integrator=euler: mean=89.43% std=0.00% over seeds=[0]
#
# === Model IzhSNN integrator=symplectic seed=0 dt=0.5 ===
# Epoch 00: loss=1.0473, train_acc=71.40%, test_acc=81.75%, elapsed=0.74min
# Epoch 01: loss=0.5857, train_acc=82.65%, test_acc=84.63%, elapsed=1.48min
# Epoch 02: loss=0.5181, train_acc=84.48%, test_acc=85.59%, elapsed=2.22min
# Epoch 03: loss=0.4769, train_acc=85.87%, test_acc=86.42%, elapsed=2.96min
# Epoch 04: loss=0.4498, train_acc=86.65%, test_acc=87.62%, elapsed=3.70min
# Epoch 05: loss=0.4286, train_acc=87.38%, test_acc=88.64%, elapsed=4.45min
# Epoch 06: loss=0.4080, train_acc=88.07%, test_acc=88.59%, elapsed=5.18min
# Epoch 07: loss=0.3885, train_acc=88.59%, test_acc=89.25%, elapsed=5.92min
# Epoch 08: loss=0.3760, train_acc=89.01%, test_acc=89.11%, elapsed=6.67min
# Epoch 09: loss=0.3615, train_acc=89.35%, test_acc=89.69%, elapsed=7.40min
# --> IzhSNN integrator=symplectic: mean=89.69% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=euler seed=0 dt=0.5 ===
# Epoch 00: loss=1.0653, train_acc=68.31%, test_acc=80.02%, elapsed=0.55min
# Epoch 01: loss=0.6355, train_acc=81.22%, test_acc=83.15%, elapsed=1.10min
# Epoch 02: loss=0.5606, train_acc=83.62%, test_acc=85.15%, elapsed=1.64min
# Epoch 03: loss=0.5120, train_acc=85.01%, test_acc=86.44%, elapsed=2.18min
# Epoch 04: loss=0.4763, train_acc=86.03%, test_acc=87.08%, elapsed=2.73min
# Epoch 05: loss=0.4428, train_acc=87.24%, test_acc=88.37%, elapsed=3.27min
# Epoch 06: loss=0.4209, train_acc=87.76%, test_acc=88.31%, elapsed=3.80min
# Epoch 07: loss=0.3965, train_acc=88.35%, test_acc=88.98%, elapsed=4.34min
# Epoch 08: loss=0.3804, train_acc=88.81%, test_acc=89.03%, elapsed=4.89min
# Epoch 09: loss=0.3590, train_acc=89.47%, test_acc=89.76%, elapsed=5.42min
# --> LIFSNN integrator=euler: mean=89.76% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=exp seed=0 dt=0.5 ===
# Epoch 00: loss=1.0843, train_acc=67.96%, test_acc=79.78%, elapsed=0.55min
# Epoch 01: loss=0.6399, train_acc=80.98%, test_acc=83.14%, elapsed=1.10min
# Epoch 02: loss=0.5676, train_acc=83.26%, test_acc=84.71%, elapsed=1.64min
# Epoch 03: loss=0.5201, train_acc=84.87%, test_acc=86.41%, elapsed=2.18min
# Epoch 04: loss=0.4793, train_acc=86.06%, test_acc=87.31%, elapsed=2.72min
# Epoch 05: loss=0.4508, train_acc=86.97%, test_acc=87.89%, elapsed=3.26min
# Epoch 06: loss=0.4257, train_acc=87.69%, test_acc=88.00%, elapsed=3.80min
# Epoch 07: loss=0.4030, train_acc=88.26%, test_acc=88.96%, elapsed=4.34min
# Epoch 08: loss=0.3874, train_acc=88.61%, test_acc=89.12%, elapsed=4.89min
# Epoch 09: loss=0.3702, train_acc=89.25%, test_acc=89.83%, elapsed=5.43min
# --> LIFSNN integrator=exp: mean=89.83% std=0.00% over seeds=[0]
#
# All experiments finished. Results saved to results.csv
# {'model': 'IzhSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [89.43], 'mean_acc': 89.43, 'std_acc': 0.0}
# {'model': 'IzhSNN', 'integrator': 'symplectic', 'seeds': [0], 'accs': [89.69], 'mean_acc': 89.69, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [89.76], 'mean_acc': 89.76, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'exp', 'seeds': [0], 'accs': [89.83], 'mean_acc': 89.83, 'std_acc': 0.0}

# %%
if __name__ == "__main__":
    dt=1.0
    encoder.reset(dt=dt)
    results = run_grid_experiments(SEEDS, dt, T, EPOCHS=10)
    # печать финальной сводки
    for r in results:
        print(r)
# Out:
# === Model IzhSNN integrator=euler seed=0 dt=1.0 ===
# Epoch 00: loss=0.7486, train_acc=79.79%, test_acc=87.07%, elapsed=0.74min
# Epoch 01: loss=0.4156, train_acc=87.68%, test_acc=89.08%, elapsed=1.48min
# Epoch 02: loss=0.3551, train_acc=89.43%, test_acc=90.48%, elapsed=2.22min
# Epoch 03: loss=0.3144, train_acc=90.78%, test_acc=91.46%, elapsed=2.95min
# Epoch 04: loss=0.2890, train_acc=91.42%, test_acc=92.36%, elapsed=3.69min
# Epoch 05: loss=0.2715, train_acc=91.82%, test_acc=92.66%, elapsed=4.43min
# Epoch 06: loss=0.2528, train_acc=92.40%, test_acc=92.61%, elapsed=5.16min
# Epoch 07: loss=0.2445, train_acc=92.59%, test_acc=92.85%, elapsed=5.90min
# Epoch 08: loss=0.2355, train_acc=92.90%, test_acc=92.83%, elapsed=6.64min
# Epoch 09: loss=0.2256, train_acc=93.09%, test_acc=93.11%, elapsed=7.37min
# --> IzhSNN integrator=euler: mean=93.11% std=0.00% over seeds=[0]
#
# === Model IzhSNN integrator=symplectic seed=0 dt=1.0 ===
# Epoch 00: loss=0.7239, train_acc=80.62%, test_acc=88.01%, elapsed=0.74min
# Epoch 01: loss=0.3977, train_acc=88.16%, test_acc=89.76%, elapsed=1.47min
# Epoch 02: loss=0.3395, train_acc=89.83%, test_acc=90.75%, elapsed=2.21min
# Epoch 03: loss=0.2995, train_acc=91.02%, test_acc=91.77%, elapsed=2.95min
# Epoch 04: loss=0.2739, train_acc=91.82%, test_acc=92.13%, elapsed=3.70min
# Epoch 05: loss=0.2560, train_acc=92.29%, test_acc=92.83%, elapsed=4.42min
# Epoch 06: loss=0.2394, train_acc=92.89%, test_acc=92.94%, elapsed=5.16min
# Epoch 07: loss=0.2272, train_acc=93.05%, test_acc=93.17%, elapsed=5.90min
# Epoch 08: loss=0.2189, train_acc=93.38%, test_acc=93.29%, elapsed=6.63min
# Epoch 09: loss=0.2110, train_acc=93.58%, test_acc=93.71%, elapsed=7.37min
# --> IzhSNN integrator=symplectic: mean=93.71% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=euler seed=0 dt=1.0 ===
# Epoch 00: loss=0.7257, train_acc=78.53%, test_acc=86.56%, elapsed=0.54min
# Epoch 01: loss=0.4039, train_acc=87.73%, test_acc=89.88%, elapsed=1.08min
# Epoch 02: loss=0.3261, train_acc=89.98%, test_acc=91.41%, elapsed=1.63min
# Epoch 03: loss=0.2739, train_acc=91.63%, test_acc=92.42%, elapsed=2.17min
# Epoch 04: loss=0.2412, train_acc=92.69%, test_acc=93.62%, elapsed=2.70min
# Epoch 05: loss=0.2176, train_acc=93.33%, test_acc=93.60%, elapsed=3.24min
# Epoch 06: loss=0.1955, train_acc=94.01%, test_acc=94.18%, elapsed=3.79min
# Epoch 07: loss=0.1842, train_acc=94.29%, test_acc=94.68%, elapsed=4.33min
# Epoch 08: loss=0.1684, train_acc=94.81%, test_acc=94.73%, elapsed=4.87min
# Epoch 09: loss=0.1581, train_acc=95.03%, test_acc=94.78%, elapsed=5.42min
# --> LIFSNN integrator=euler: mean=94.78% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=exp seed=0 dt=1.0 ===
# Epoch 00: loss=0.7645, train_acc=78.00%, test_acc=86.04%, elapsed=0.54min
# Epoch 01: loss=0.4331, train_acc=87.05%, test_acc=89.35%, elapsed=1.09min
# Epoch 02: loss=0.3580, train_acc=89.31%, test_acc=90.39%, elapsed=1.63min
# Epoch 03: loss=0.3052, train_acc=90.87%, test_acc=91.74%, elapsed=2.18min
# Epoch 04: loss=0.2738, train_acc=91.72%, test_acc=92.83%, elapsed=2.72min
# Epoch 05: loss=0.2471, train_acc=92.53%, test_acc=92.92%, elapsed=3.26min
# Epoch 06: loss=0.2234, train_acc=93.24%, test_acc=93.04%, elapsed=3.80min
# Epoch 07: loss=0.2083, train_acc=93.62%, test_acc=94.04%, elapsed=4.34min
# Epoch 08: loss=0.1956, train_acc=94.05%, test_acc=94.27%, elapsed=4.88min
# Epoch 09: loss=0.1840, train_acc=94.28%, test_acc=94.30%, elapsed=5.43min
# --> LIFSNN integrator=exp: mean=94.30% std=0.00% over seeds=[0]
#
# All experiments finished. Results saved to results.csv
# {'model': 'IzhSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [93.11], 'mean_acc': 93.11, 'std_acc': 0.0}
# {'model': 'IzhSNN', 'integrator': 'symplectic', 'seeds': [0], 'accs': [93.71], 'mean_acc': 93.71, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [94.78], 'mean_acc': 94.78, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'exp', 'seeds': [0], 'accs': [94.3], 'mean_acc': 94.3, 'std_acc': 0.0}

# %%
if __name__ == "__main__":
    dt=2.0
    encoder.reset(dt=dt)
    results = run_grid_experiments(SEEDS, dt, T, EPOCHS=10)
    # печать финальной сводки
    for r in results:
        print(r)
# Out:
# === Model IzhSNN integrator=euler seed=0 dt=2.0 ===
# Epoch 00: loss=0.5554, train_acc=84.60%, test_acc=89.51%, elapsed=0.74min
# Epoch 01: loss=0.3593, train_acc=88.99%, test_acc=89.46%, elapsed=1.47min
# Epoch 02: loss=0.3366, train_acc=89.52%, test_acc=90.75%, elapsed=2.21min
# Epoch 03: loss=0.3133, train_acc=90.14%, test_acc=90.31%, elapsed=2.94min
# Epoch 04: loss=0.3137, train_acc=90.18%, test_acc=90.26%, elapsed=3.68min
# Epoch 05: loss=0.3101, train_acc=90.35%, test_acc=90.82%, elapsed=4.42min
# Epoch 06: loss=0.2958, train_acc=90.83%, test_acc=90.98%, elapsed=5.15min
# Epoch 07: loss=0.2985, train_acc=90.72%, test_acc=90.75%, elapsed=5.88min
# Epoch 08: loss=0.2866, train_acc=91.11%, test_acc=90.98%, elapsed=6.62min
# Epoch 09: loss=0.2809, train_acc=91.16%, test_acc=91.35%, elapsed=7.36min
# --> IzhSNN integrator=euler: mean=91.35% std=0.00% over seeds=[0]
#
# === Model IzhSNN integrator=symplectic seed=0 dt=2.0 ===
# Epoch 00: loss=0.5244, train_acc=85.75%, test_acc=90.19%, elapsed=0.74min
# Epoch 01: loss=0.3267, train_acc=90.07%, test_acc=90.34%, elapsed=1.47min
# Epoch 02: loss=0.3130, train_acc=90.39%, test_acc=90.92%, elapsed=2.21min
# Epoch 03: loss=0.2936, train_acc=90.87%, test_acc=91.17%, elapsed=2.95min
# Epoch 04: loss=0.2912, train_acc=90.92%, test_acc=91.15%, elapsed=3.69min
# Epoch 05: loss=0.2792, train_acc=91.27%, test_acc=90.98%, elapsed=4.44min
# Epoch 06: loss=0.2872, train_acc=91.05%, test_acc=91.12%, elapsed=5.18min
# Epoch 07: loss=0.2812, train_acc=91.27%, test_acc=91.30%, elapsed=5.92min
# Epoch 08: loss=0.2738, train_acc=91.40%, test_acc=91.79%, elapsed=6.67min
# Epoch 09: loss=0.2674, train_acc=91.71%, test_acc=91.24%, elapsed=7.40min
# --> IzhSNN integrator=symplectic: mean=91.24% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=euler seed=0 dt=2.0 ===
# Epoch 00: loss=0.4302, train_acc=87.49%, test_acc=92.84%, elapsed=0.54min
# Epoch 01: loss=0.2042, train_acc=93.94%, test_acc=94.56%, elapsed=1.08min
# Epoch 02: loss=0.1575, train_acc=95.30%, test_acc=95.34%, elapsed=1.61min
# Epoch 03: loss=0.1297, train_acc=96.14%, test_acc=95.63%, elapsed=2.16min
# Epoch 04: loss=0.1143, train_acc=96.50%, test_acc=96.15%, elapsed=2.71min
# Epoch 05: loss=0.1020, train_acc=96.86%, test_acc=96.20%, elapsed=3.24min
# Epoch 06: loss=0.0908, train_acc=97.23%, test_acc=96.64%, elapsed=3.79min
# Epoch 07: loss=0.0824, train_acc=97.44%, test_acc=96.69%, elapsed=4.33min
# Epoch 08: loss=0.0765, train_acc=97.58%, test_acc=96.57%, elapsed=4.87min
# Epoch 09: loss=0.0729, train_acc=97.71%, test_acc=96.77%, elapsed=5.41min
# --> LIFSNN integrator=euler: mean=96.77% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=exp seed=0 dt=2.0 ===
# Epoch 00: loss=0.5175, train_acc=84.81%, test_acc=90.96%, elapsed=0.55min
# Epoch 01: loss=0.2605, train_acc=92.10%, test_acc=93.22%, elapsed=1.09min
# Epoch 02: loss=0.2004, train_acc=93.96%, test_acc=94.46%, elapsed=1.63min
# Epoch 03: loss=0.1633, train_acc=95.03%, test_acc=95.20%, elapsed=2.17min
# Epoch 04: loss=0.1404, train_acc=95.67%, test_acc=95.57%, elapsed=2.72min
# Epoch 05: loss=0.1266, train_acc=96.04%, test_acc=95.73%, elapsed=3.25min
# Epoch 06: loss=0.1123, train_acc=96.54%, test_acc=96.30%, elapsed=3.80min
# Epoch 07: loss=0.1027, train_acc=96.73%, test_acc=96.36%, elapsed=4.35min
# Epoch 08: loss=0.0948, train_acc=97.09%, test_acc=96.50%, elapsed=4.89min
# Epoch 09: loss=0.0869, train_acc=97.26%, test_acc=96.50%, elapsed=5.43min
# --> LIFSNN integrator=exp: mean=96.50% std=0.00% over seeds=[0]
#
# All experiments finished. Results saved to results.csv
# {'model': 'IzhSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [91.35], 'mean_acc': 91.35, 'std_acc': 0.0}
# {'model': 'IzhSNN', 'integrator': 'symplectic', 'seeds': [0], 'accs': [91.24], 'mean_acc': 91.24, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [96.77], 'mean_acc': 96.77, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'exp', 'seeds': [0], 'accs': [96.5], 'mean_acc': 96.5, 'std_acc': 0.0}

# %%
if __name__ == "__main__":
    dt=5.0
    encoder.reset(dt=dt)
    results = run_grid_experiments(SEEDS, dt, T, EPOCHS=10)
    # печать финальной сводки
    for r in results:
        print(r)
# Out:
# === Model IzhSNN integrator=euler seed=0 dt=5.0 ===
# Epoch 00: loss=2.3026, train_acc=9.87%, test_acc=9.80%, elapsed=0.74min
# Epoch 01: loss=2.3026, train_acc=9.88%, test_acc=9.80%, elapsed=1.48min
# Epoch 02: loss=2.3026, train_acc=9.87%, test_acc=9.80%, elapsed=2.22min
# Epoch 03: loss=2.3026, train_acc=9.88%, test_acc=9.80%, elapsed=2.96min
# Epoch 04: loss=2.3026, train_acc=9.87%, test_acc=9.80%, elapsed=3.70min
# Epoch 05: loss=2.3026, train_acc=9.86%, test_acc=9.80%, elapsed=4.44min
# Epoch 06: loss=2.3026, train_acc=9.86%, test_acc=9.80%, elapsed=5.17min
# Epoch 07: loss=2.3026, train_acc=9.86%, test_acc=9.80%, elapsed=5.92min
# Epoch 08: loss=2.3026, train_acc=9.87%, test_acc=9.80%, elapsed=6.65min
# Epoch 09: loss=2.3026, train_acc=9.88%, test_acc=9.80%, elapsed=7.39min
# --> IzhSNN integrator=euler: mean=9.80% std=0.00% over seeds=[0]
#
# === Model IzhSNN integrator=symplectic seed=0 dt=5.0 ===
# Epoch 00: loss=1.4010, train_acc=61.78%, test_acc=74.36%, elapsed=0.74min
# Epoch 01: loss=0.8083, train_acc=76.37%, test_acc=78.81%, elapsed=1.47min
# Epoch 02: loss=0.6683, train_acc=79.29%, test_acc=81.59%, elapsed=2.21min
# Epoch 03: loss=0.6104, train_acc=81.14%, test_acc=82.22%, elapsed=2.95min
# Epoch 04: loss=0.5783, train_acc=81.80%, test_acc=83.15%, elapsed=3.68min
# Epoch 05: loss=0.5361, train_acc=83.11%, test_acc=83.42%, elapsed=4.43min
# Epoch 06: loss=0.5236, train_acc=83.50%, test_acc=83.49%, elapsed=5.17min
# Epoch 07: loss=0.5131, train_acc=83.58%, test_acc=83.99%, elapsed=5.90min
# Epoch 08: loss=0.5043, train_acc=84.03%, test_acc=84.06%, elapsed=6.64min
# Epoch 09: loss=0.5098, train_acc=83.84%, test_acc=84.57%, elapsed=7.38min
# --> IzhSNN integrator=symplectic: mean=84.57% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=euler seed=0 dt=5.0 ===
# Epoch 00: loss=1.3995, train_acc=60.22%, test_acc=66.29%, elapsed=0.53min
# Epoch 01: loss=1.0751, train_acc=67.63%, test_acc=69.99%, elapsed=1.08min
# Epoch 02: loss=1.0019, train_acc=69.16%, test_acc=69.15%, elapsed=1.63min
# Epoch 03: loss=1.0934, train_acc=64.40%, test_acc=66.08%, elapsed=2.17min
# Epoch 04: loss=1.0326, train_acc=66.40%, test_acc=64.85%, elapsed=2.71min
# Epoch 05: loss=1.1315, train_acc=62.82%, test_acc=63.23%, elapsed=3.26min
# Epoch 06: loss=1.1261, train_acc=63.15%, test_acc=63.07%, elapsed=3.81min
# Epoch 07: loss=1.1633, train_acc=61.65%, test_acc=63.36%, elapsed=4.35min
# Epoch 08: loss=1.1404, train_acc=63.19%, test_acc=65.54%, elapsed=4.90min
# Epoch 09: loss=1.1306, train_acc=63.61%, test_acc=63.12%, elapsed=5.44min
# --> LIFSNN integrator=euler: mean=63.12% std=0.00% over seeds=[0]
#
# === Model LIFSNN integrator=exp seed=0 dt=5.0 ===
# Epoch 00: loss=0.3824, train_acc=89.10%, test_acc=93.89%, elapsed=0.54min
# Epoch 01: loss=0.1710, train_acc=94.98%, test_acc=95.52%, elapsed=1.09min
# Epoch 02: loss=0.1258, train_acc=96.26%, test_acc=96.14%, elapsed=1.64min
# Epoch 03: loss=0.1010, train_acc=97.04%, test_acc=96.79%, elapsed=2.19min
# Epoch 04: loss=0.0846, train_acc=97.46%, test_acc=96.77%, elapsed=2.72min
# Epoch 05: loss=0.0730, train_acc=97.85%, test_acc=96.96%, elapsed=3.26min
# Epoch 06: loss=0.0616, train_acc=98.24%, test_acc=97.22%, elapsed=3.81min
# Epoch 07: loss=0.0542, train_acc=98.39%, test_acc=97.19%, elapsed=4.34min
# Epoch 08: loss=0.0473, train_acc=98.56%, test_acc=97.30%, elapsed=4.89min
# Epoch 09: loss=0.0424, train_acc=98.79%, test_acc=97.47%, elapsed=5.43min
# --> LIFSNN integrator=exp: mean=97.47% std=0.00% over seeds=[0]
#
# All experiments finished. Results saved to results.csv
# {'model': 'IzhSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [9.8], 'mean_acc': 9.8, 'std_acc': 0.0}
# {'model': 'IzhSNN', 'integrator': 'symplectic', 'seeds': [0], 'accs': [84.57], 'mean_acc': 84.57, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'euler', 'seeds': [0], 'accs': [63.12], 'mean_acc': 63.12, 'std_acc': 0.0}
# {'model': 'LIFSNN', 'integrator': 'exp', 'seeds': [0], 'accs': [97.47], 'mean_acc': 97.47, 'std_acc': 0.0}

# %% [markdown]
# # 12. Исследование режима T=50, dt=5.0

# %%
@dataclass
class SpikeStats:
    total_spikes: float = 0.0
    total_sites: int = 0          # суммарно B*N по всем шагам и батчам
    silent_sites: int = 0
    active_sites: int = 0

    def update(self, s: torch.Tensor):
        # s: ожидаем [B, N] (0/1), но на всякий приведём
        with torch.no_grad():
            if s.dim() == 1:
                s = s.unsqueeze(0)
            else:
                s = s.view(s.size(0), -1)

            B, N = s.shape
            sites = B * N
            self.total_sites += int(sites)

            active = (s > 0).sum().item()
            silent = sites - active

            self.active_sites += int(active)
            self.silent_sites += int(silent)
            self.total_spikes += float(active)  # если строго 0/1

    def summary(self):
        denom = max(1, self.total_sites)
        active_frac = self.active_sites / denom
        silent_frac = self.silent_sites / denom
        mean_spike_rate = self.total_spikes / denom  # == active_frac для 0/1

        return {
            "mean_spike_rate": float(mean_spike_rate),
            "silent_frac": float(silent_frac),
            "active_frac": float(active_frac)
        }

# %%
class IzhSNN(nn.Module):
    def __init__(self, integrator='euler', dt=1.0, T=50):
        super().__init__()
        self.T = int(T)

        self.fc1 = nn.Linear(28 * 28, 256, bias=False)

        self.neuron1 = neuron.IzhikevichNode(
            tau=2.0,
            v_c=0.8,
            a0=1.0,
            v_threshold=1.0,
            v_reset=0.0,
            v_rest=-0.1,
            w_rest=0.0,
            tau_w=2.0,
            a=0.02,
            b=0.2,
            surrogate_function=surrogate.Sigmoid(),
            integrator=integrator,
            dt=float(dt)
        )

        self.fc_out = nn.Linear(256, 10, bias=False)

    def forward(self, x, collect_stats=False):
        x = x.view(x.size(0), -1)

        out_accum = None
        stats = SpikeStats() if collect_stats else None

        for _ in range(self.T):
            x_t = encoder(x)
            h = self.fc1(x_t)
            s = self.neuron1(h)

            if collect_stats:
                stats.update(s)

            out = self.fc_out(s)

            if out_accum is None:
                out_accum = out
            else:
                out_accum = torch.maximum(out_accum, out)

        return (out_accum, stats) if collect_stats else out_accum

# %%
class LIFSNN(nn.Module):
    def __init__(self, integrator='euler', dt=1.0, T=50):
        super().__init__()
        self.T = int(T)

        self.fc1 = nn.Linear(28 * 28, 256, bias=False)

        self.neuron1 = neuron.LIFNode(
            tau=2.0,
            decay_input=True,
            v_threshold=1.0,
            v_reset=0.0,
            surrogate_function=surrogate.Sigmoid(),
            integrator=integrator,   # 'euler' или 'exp'
            dt=float(dt)
        )

        self.fc_out = nn.Linear(256, 10, bias=False)

    def forward(self, x, collect_stats=False):
        x = x.view(x.size(0), -1)

        out_accum = None
        stats = SpikeStats() if collect_stats else None

        for _ in range(self.T):
            x_t = encoder(x)
            h = self.fc1(x_t)
            s = self.neuron1(h)

            if collect_stats:
                stats.update(s)

            out = self.fc_out(s)

            if out_accum is None:
                out_accum = out
            else:
                out_accum = torch.maximum(out_accum, out)

        return (out_accum, stats) if collect_stats else out_accum

# %%
@torch.no_grad()
def evaluate_with_stats(model, loader, max_batches=None):
    model.eval()
    agg = SpikeStats()

    correct = 0
    total = 0

    for bi, (x, y) in enumerate(loader):
        if max_batches is not None and bi >= max_batches:
            break

        x = x.to(DEVICE)
        y = y.to(DEVICE)

        functional.reset_net(model)

        out, stats = model(x, collect_stats=True)  # <-- вот так, без костылей

        pred = out.argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.size(0)

        # аккуратно агрегируем
        agg.total_spikes += stats.total_spikes
        agg.total_sites  += stats.total_sites
        agg.silent_sites += stats.silent_sites
        agg.active_sites += stats.active_sites

    acc = 100.0 * correct / max(1, total)
    return acc, agg.summary()

# %%
def run_dt5_suite(model_cls, integrators, seeds, T, dt, EPOCHS):
    rows = []

    for integ in integrators:
        for seed in seeds:
            print(f"\n=== {model_cls.__name__} integ={integ} seed={seed} dt={dt} T={T} ===")

            set_seed(seed)
            encoder.reset(dt=dt)

            model = model_cls(integrator=integ, T=T, dt=dt).to(DEVICE)
            optimizer = optim.Adam(model.parameters(), lr=LR)
            criterion = nn.CrossEntropyLoss()

            for epoch in range(EPOCHS):
                train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion)
                test_acc, test_stats = evaluate_with_stats(model, test_loader, max_batches=10)

                print(
                    f"Epoch {epoch:02d}: loss={train_loss:.4f}, "
                    f"train_acc={train_acc:.2f}%, test_acc={test_acc:.2f}%, "
                    f"spike_rate={test_stats['mean_spike_rate']:.4e}, "
                    f"silent={test_stats['silent_frac']:.3f}, active={test_stats['active_frac']:.3f}"
                )

            final_acc, final_stats = evaluate_with_stats(model, test_loader, max_batches=50)

            rows.append({
                "model": model_cls.__name__,
                "integrator": integ,
                "seed": seed,
                "dt": float(dt),
                "T": int(T),
                "final_acc": float(final_acc),
                "final_mean_spike_rate": final_stats["mean_spike_rate"],
                "final_silent_frac": final_stats["silent_frac"],
                "final_active_frac": final_stats["active_frac"],
            })

    return pd.DataFrame(rows)

# %%
dt = 5.0
T = 50
EPOCHS = 10
SEEDS = [0, 1, 2, 3, 4]

df_izh = run_dt5_suite(
    IzhSNN,
    integrators=["euler", "symplectic"],
    seeds=SEEDS,
    T=T,
    dt=dt,
    EPOCHS=EPOCHS
)

display(df_izh)
df_izh.to_csv("dt5_stats_izh.csv", index=False)
print("Saved to dt5_stats_izh.csv")
# Out:
# === IzhSNN integ=euler seed=0 dt=5.0 T=50 ===
# Epoch 00: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 01: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 02: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 03: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 04: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 05: loss=2.3026, train_acc=9.86%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 06: loss=2.3026, train_acc=9.86%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 07: loss=2.3026, train_acc=9.86%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 08: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 09: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
#
# === IzhSNN integ=euler seed=1 dt=5.0 T=50 ===
# Epoch 00: loss=2.3027, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 01: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 02: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 03: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 04: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 05: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 06: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 07: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 08: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 09: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
#
# === IzhSNN integ=euler seed=2 dt=5.0 T=50 ===
# Epoch 00: loss=2.3027, train_acc=9.86%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 01: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 02: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 03: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 04: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 05: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 06: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 07: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 08: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 09: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
#
# === IzhSNN integ=euler seed=3 dt=5.0 T=50 ===
# Epoch 00: loss=2.3026, train_acc=9.86%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 01: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 02: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 03: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 04: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 05: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 06: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 07: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 08: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 09: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
#
# === IzhSNN integ=euler seed=4 dt=5.0 T=50 ===
# Epoch 00: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 01: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 02: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 03: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 04: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 05: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 06: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 07: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 08: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 09: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
#
# === IzhSNN integ=symplectic seed=0 dt=5.0 T=50 ===
# Epoch 00: loss=1.4561, train_acc=62.57%, test_acc=68.98%, spike_rate=5.0369e-01, silent=0.496, active=0.504
# Epoch 01: loss=0.9243, train_acc=75.82%, test_acc=76.02%, spike_rate=5.0640e-01, silent=0.494, active=0.506
# Epoch 02: loss=0.7932, train_acc=77.30%, test_acc=76.56%, spike_rate=5.0822e-01, silent=0.492, active=0.508
# Epoch 03: loss=0.6937, train_acc=79.31%, test_acc=76.95%, spike_rate=5.1203e-01, silent=0.488, active=0.512
# Epoch 04: loss=0.6554, train_acc=80.08%, test_acc=78.91%, spike_rate=5.1374e-01, silent=0.486, active=0.514
# Epoch 05: loss=0.6433, train_acc=80.10%, test_acc=76.64%, spike_rate=5.1519e-01, silent=0.485, active=0.515
# Epoch 06: loss=0.6454, train_acc=79.89%, test_acc=76.02%, spike_rate=5.1718e-01, silent=0.483, active=0.517
# Epoch 07: loss=0.6508, train_acc=79.45%, test_acc=76.41%, spike_rate=5.2012e-01, silent=0.480, active=0.520
# Epoch 08: loss=0.6525, train_acc=79.87%, test_acc=79.14%, spike_rate=5.2100e-01, silent=0.479, active=0.521
# Epoch 09: loss=0.6333, train_acc=80.25%, test_acc=76.80%, spike_rate=5.2162e-01, silent=0.478, active=0.522
#
# === IzhSNN integ=symplectic seed=1 dt=5.0 T=50 ===
# Epoch 00: loss=1.4103, train_acc=63.96%, test_acc=73.98%, spike_rate=5.0418e-01, silent=0.496, active=0.504
# Epoch 01: loss=0.8108, train_acc=78.43%, test_acc=77.19%, spike_rate=5.1228e-01, silent=0.488, active=0.512
# Epoch 02: loss=0.7477, train_acc=78.64%, test_acc=78.12%, spike_rate=5.1424e-01, silent=0.486, active=0.514
# Epoch 03: loss=0.6879, train_acc=79.70%, test_acc=79.92%, spike_rate=5.1582e-01, silent=0.484, active=0.516
# Epoch 04: loss=0.6434, train_acc=80.75%, test_acc=79.92%, spike_rate=5.1866e-01, silent=0.481, active=0.519
# Epoch 05: loss=0.6129, train_acc=81.39%, test_acc=80.62%, spike_rate=5.1958e-01, silent=0.480, active=0.520
# Epoch 06: loss=0.6005, train_acc=81.54%, test_acc=78.52%, spike_rate=5.2065e-01, silent=0.479, active=0.521
# Epoch 07: loss=0.5932, train_acc=81.73%, test_acc=79.45%, spike_rate=5.2076e-01, silent=0.479, active=0.521
# Epoch 08: loss=0.6130, train_acc=81.03%, test_acc=77.97%, spike_rate=5.2169e-01, silent=0.478, active=0.522
# Epoch 09: loss=0.6078, train_acc=80.73%, test_acc=77.81%, spike_rate=5.2279e-01, silent=0.477, active=0.523
#
# === IzhSNN integ=symplectic seed=2 dt=5.0 T=50 ===
# Epoch 00: loss=1.4322, train_acc=63.51%, test_acc=72.11%, spike_rate=5.0328e-01, silent=0.497, active=0.503
# Epoch 01: loss=0.8291, train_acc=78.29%, test_acc=77.34%, spike_rate=5.0847e-01, silent=0.492, active=0.508
# Epoch 02: loss=0.7140, train_acc=80.11%, test_acc=79.84%, spike_rate=5.1305e-01, silent=0.487, active=0.513
# Epoch 03: loss=0.6780, train_acc=80.75%, test_acc=77.58%, spike_rate=5.1458e-01, silent=0.485, active=0.515
# Epoch 04: loss=0.6469, train_acc=81.13%, test_acc=78.12%, spike_rate=5.1778e-01, silent=0.482, active=0.518
# Epoch 05: loss=0.6297, train_acc=81.19%, test_acc=78.67%, spike_rate=5.1976e-01, silent=0.480, active=0.520
# Epoch 06: loss=0.6566, train_acc=79.93%, test_acc=79.77%, spike_rate=5.2017e-01, silent=0.480, active=0.520
# Epoch 07: loss=0.6589, train_acc=79.61%, test_acc=76.64%, spike_rate=5.2121e-01, silent=0.479, active=0.521
# Epoch 08: loss=0.6416, train_acc=80.01%, test_acc=77.58%, spike_rate=5.2226e-01, silent=0.478, active=0.522
# Epoch 09: loss=0.6263, train_acc=80.43%, test_acc=76.02%, spike_rate=5.2238e-01, silent=0.478, active=0.522
#
# === IzhSNN integ=symplectic seed=3 dt=5.0 T=50 ===
# Epoch 00: loss=1.3943, train_acc=64.60%, test_acc=74.92%, spike_rate=5.0286e-01, silent=0.497, active=0.503
# Epoch 01: loss=0.7931, train_acc=79.30%, test_acc=76.72%, spike_rate=5.1034e-01, silent=0.490, active=0.510
# Epoch 02: loss=0.7003, train_acc=80.49%, test_acc=79.69%, spike_rate=5.1597e-01, silent=0.484, active=0.516
# Epoch 03: loss=0.6416, train_acc=81.59%, test_acc=76.09%, spike_rate=5.1888e-01, silent=0.481, active=0.519
# Epoch 04: loss=0.6485, train_acc=80.55%, test_acc=78.05%, spike_rate=5.2221e-01, silent=0.478, active=0.522
# Epoch 05: loss=0.6332, train_acc=80.60%, test_acc=76.95%, spike_rate=5.2332e-01, silent=0.477, active=0.523
# Epoch 06: loss=0.6384, train_acc=80.38%, test_acc=77.19%, spike_rate=5.2636e-01, silent=0.474, active=0.526
# Epoch 07: loss=0.6650, train_acc=79.40%, test_acc=75.31%, spike_rate=5.2723e-01, silent=0.473, active=0.527
# Epoch 08: loss=0.6864, train_acc=78.81%, test_acc=75.47%, spike_rate=5.2765e-01, silent=0.472, active=0.528
# Epoch 09: loss=0.6912, train_acc=78.51%, test_acc=74.61%, spike_rate=5.2777e-01, silent=0.472, active=0.528
#
# === IzhSNN integ=symplectic seed=4 dt=5.0 T=50 ===
# Epoch 00: loss=1.4358, train_acc=63.16%, test_acc=76.48%, spike_rate=4.9950e-01, silent=0.501, active=0.499
# Epoch 01: loss=0.7537, train_acc=79.73%, test_acc=78.67%, spike_rate=5.0557e-01, silent=0.494, active=0.506
# Epoch 02: loss=0.6904, train_acc=80.62%, test_acc=80.23%, spike_rate=5.1070e-01, silent=0.489, active=0.511
# Epoch 03: loss=0.6444, train_acc=81.04%, test_acc=78.52%, spike_rate=5.1500e-01, silent=0.485, active=0.515
# Epoch 04: loss=0.6088, train_acc=81.54%, test_acc=80.39%, spike_rate=5.1621e-01, silent=0.484, active=0.516
# Epoch 05: loss=0.6118, train_acc=81.34%, test_acc=77.73%, spike_rate=5.1825e-01, silent=0.482, active=0.518
# Epoch 06: loss=0.6518, train_acc=79.91%, test_acc=77.58%, spike_rate=5.2198e-01, silent=0.478, active=0.522
# Epoch 07: loss=0.6854, train_acc=79.01%, test_acc=79.14%, spike_rate=5.2324e-01, silent=0.477, active=0.523
# Epoch 08: loss=0.6551, train_acc=79.44%, test_acc=75.31%, spike_rate=5.2348e-01, silent=0.477, active=0.523
# Epoch 09: loss=0.7373, train_acc=76.73%, test_acc=73.67%, spike_rate=5.2477e-01, silent=0.475, active=0.525
#     model  integrator  seed   dt   T  final_acc  final_mean_spike_rate  \
# 0  IzhSNN       euler     0  5.0  50   9.468750               0.000000
# 1  IzhSNN       euler     1  5.0  50   9.468750               0.000000
# 2  IzhSNN       euler     2  5.0  50   9.468750               0.000000
# 3  IzhSNN       euler     3  5.0  50   9.468750               0.000000
# 4  IzhSNN       euler     4  5.0  50   9.468750               0.000000
# 5  IzhSNN  symplectic     0  5.0  50  77.750000               0.522346
# 6  IzhSNN  symplectic     1  5.0  50  80.453125               0.523586
# 7  IzhSNN  symplectic     2  5.0  50  78.015625               0.523141
# 8  IzhSNN  symplectic     3  5.0  50  77.250000               0.528478
# 9  IzhSNN  symplectic     4  5.0  50  74.890625               0.525523
#
#    final_silent_frac  final_active_frac
# 0           1.000000           0.000000
# 1           1.000000           0.000000
# 2           1.000000           0.000000
# 3           1.000000           0.000000
# 4           1.000000           0.000000
# 5           0.477654           0.522346
# 6           0.476414           0.523586
# 7           0.476859           0.523141
# 8           0.471522           0.528478
# 9           0.474477           0.525523
# Saved to dt5_stats_izh.csv

# %%
dt = 5.0
T = 50
EPOCHS = 10
SEEDS = [0, 1, 2, 3, 4]

df_lif = run_dt5_suite(
    LIFSNN,
    integrators=["euler", "exp"],
    seeds=SEEDS,
    T=T,
    dt=dt,
    EPOCHS=EPOCHS
)

display(df_lif)
df_lif.to_csv("dt5_stats_lif.csv", index=False)
print("Saved to dt5_stats_lif.csv")
# Out:
# === LIFSNN integ=euler seed=0 dt=5.0 T=50 ===
# Epoch 00: loss=1.5321, train_acc=60.08%, test_acc=63.28%, spike_rate=5.7740e-01, silent=0.423, active=0.577
# Epoch 01: loss=1.2133, train_acc=67.02%, test_acc=63.91%, spike_rate=6.4782e-01, silent=0.352, active=0.648
# Epoch 02: loss=1.1908, train_acc=66.04%, test_acc=65.70%, spike_rate=6.6820e-01, silent=0.332, active=0.668
# Epoch 03: loss=1.0970, train_acc=68.36%, test_acc=62.81%, spike_rate=6.7853e-01, silent=0.321, active=0.679
# Epoch 04: loss=1.0977, train_acc=66.54%, test_acc=65.16%, spike_rate=6.8982e-01, silent=0.310, active=0.690
# Epoch 05: loss=1.0866, train_acc=65.93%, test_acc=62.73%, spike_rate=7.0480e-01, silent=0.295, active=0.705
# Epoch 06: loss=1.0670, train_acc=66.43%, test_acc=64.77%, spike_rate=7.1216e-01, silent=0.288, active=0.712
# Epoch 07: loss=1.0842, train_acc=65.57%, test_acc=61.95%, spike_rate=7.1762e-01, silent=0.282, active=0.718
# Epoch 08: loss=1.0487, train_acc=66.72%, test_acc=63.12%, spike_rate=7.2656e-01, silent=0.273, active=0.727
# Epoch 09: loss=1.0824, train_acc=65.80%, test_acc=64.84%, spike_rate=7.3771e-01, silent=0.262, active=0.738
#
# === LIFSNN integ=euler seed=1 dt=5.0 T=50 ===
# Epoch 00: loss=1.4865, train_acc=60.81%, test_acc=67.27%, spike_rate=5.3558e-01, silent=0.464, active=0.536
# Epoch 01: loss=1.1618, train_acc=68.53%, test_acc=65.86%, spike_rate=6.1537e-01, silent=0.385, active=0.615
# Epoch 02: loss=1.0870, train_acc=67.99%, test_acc=65.08%, spike_rate=6.4512e-01, silent=0.355, active=0.645
# Epoch 03: loss=1.0587, train_acc=67.82%, test_acc=63.83%, spike_rate=6.5032e-01, silent=0.350, active=0.650
# Epoch 04: loss=1.0882, train_acc=65.71%, test_acc=63.12%, spike_rate=6.6929e-01, silent=0.331, active=0.669
# Epoch 05: loss=1.0627, train_acc=66.38%, test_acc=65.08%, spike_rate=6.6971e-01, silent=0.330, active=0.670
# Epoch 06: loss=1.0626, train_acc=65.21%, test_acc=64.61%, spike_rate=6.7846e-01, silent=0.322, active=0.678
# Epoch 07: loss=1.0013, train_acc=67.22%, test_acc=64.38%, spike_rate=6.8516e-01, silent=0.315, active=0.685
# Epoch 08: loss=0.9863, train_acc=68.02%, test_acc=65.23%, spike_rate=6.9866e-01, silent=0.301, active=0.699
# Epoch 09: loss=1.0233, train_acc=67.23%, test_acc=65.16%, spike_rate=7.0536e-01, silent=0.295, active=0.705
#
# === LIFSNN integ=euler seed=2 dt=5.0 T=50 ===
# Epoch 00: loss=1.5126, train_acc=61.22%, test_acc=63.91%, spike_rate=5.8306e-01, silent=0.417, active=0.583
# Epoch 01: loss=1.1632, train_acc=68.71%, test_acc=66.41%, spike_rate=6.4884e-01, silent=0.351, active=0.649
# Epoch 02: loss=1.0483, train_acc=70.73%, test_acc=69.53%, spike_rate=6.7524e-01, silent=0.325, active=0.675
# Epoch 03: loss=0.9556, train_acc=72.15%, test_acc=71.64%, spike_rate=6.7898e-01, silent=0.321, active=0.679
# Epoch 04: loss=0.9521, train_acc=71.16%, test_acc=70.55%, spike_rate=6.6845e-01, silent=0.332, active=0.668
# Epoch 05: loss=0.9623, train_acc=69.66%, test_acc=67.81%, spike_rate=6.7473e-01, silent=0.325, active=0.675
# Epoch 06: loss=0.9628, train_acc=69.47%, test_acc=66.25%, spike_rate=6.8650e-01, silent=0.313, active=0.687
# Epoch 07: loss=0.9223, train_acc=70.74%, test_acc=70.47%, spike_rate=6.9592e-01, silent=0.304, active=0.696
# Epoch 08: loss=0.9371, train_acc=69.83%, test_acc=68.52%, spike_rate=6.9231e-01, silent=0.308, active=0.692
# Epoch 09: loss=0.8959, train_acc=70.87%, test_acc=69.30%, spike_rate=6.8559e-01, silent=0.314, active=0.686
#
# === LIFSNN integ=euler seed=3 dt=5.0 T=50 ===
# Epoch 00: loss=1.4519, train_acc=62.60%, test_acc=65.47%, spike_rate=5.8614e-01, silent=0.414, active=0.586
# Epoch 01: loss=1.0738, train_acc=70.15%, test_acc=69.92%, spike_rate=6.3822e-01, silent=0.362, active=0.638
# Epoch 02: loss=1.0728, train_acc=68.39%, test_acc=66.88%, spike_rate=6.7147e-01, silent=0.329, active=0.671
# Epoch 03: loss=1.0401, train_acc=69.56%, test_acc=66.72%, spike_rate=6.8009e-01, silent=0.320, active=0.680
# Epoch 04: loss=0.9839, train_acc=69.85%, test_acc=67.11%, spike_rate=6.7627e-01, silent=0.324, active=0.676
# Epoch 05: loss=1.0112, train_acc=68.51%, test_acc=66.56%, spike_rate=6.8123e-01, silent=0.319, active=0.681
# Epoch 06: loss=0.9219, train_acc=70.28%, test_acc=68.91%, spike_rate=6.8379e-01, silent=0.316, active=0.684
# Epoch 07: loss=0.8434, train_acc=72.75%, test_acc=69.92%, spike_rate=6.8566e-01, silent=0.314, active=0.686
# Epoch 08: loss=0.7759, train_acc=75.19%, test_acc=73.20%, spike_rate=6.8908e-01, silent=0.311, active=0.689
# Epoch 09: loss=0.7881, train_acc=75.08%, test_acc=71.88%, spike_rate=6.8989e-01, silent=0.310, active=0.690
#
# === LIFSNN integ=euler seed=4 dt=5.0 T=50 ===
# Epoch 00: loss=1.5672, train_acc=59.02%, test_acc=68.83%, spike_rate=5.0829e-01, silent=0.492, active=0.508
# Epoch 01: loss=1.1716, train_acc=68.70%, test_acc=64.53%, spike_rate=5.6086e-01, silent=0.439, active=0.561
# Epoch 02: loss=1.1839, train_acc=65.53%, test_acc=62.27%, spike_rate=6.0584e-01, silent=0.394, active=0.606
# Epoch 03: loss=1.1900, train_acc=63.55%, test_acc=62.97%, spike_rate=6.2375e-01, silent=0.376, active=0.624
# Epoch 04: loss=1.1846, train_acc=62.97%, test_acc=62.66%, spike_rate=6.3861e-01, silent=0.361, active=0.639
# Epoch 05: loss=1.1878, train_acc=62.92%, test_acc=64.38%, spike_rate=6.5082e-01, silent=0.349, active=0.651
# Epoch 06: loss=1.1891, train_acc=62.40%, test_acc=60.08%, spike_rate=6.5435e-01, silent=0.346, active=0.654
# Epoch 07: loss=1.0900, train_acc=66.02%, test_acc=63.28%, spike_rate=6.6082e-01, silent=0.339, active=0.661
# Epoch 08: loss=1.0651, train_acc=66.30%, test_acc=64.38%, spike_rate=6.6851e-01, silent=0.331, active=0.669
# Epoch 09: loss=1.0435, train_acc=66.56%, test_acc=63.52%, spike_rate=6.7028e-01, silent=0.330, active=0.670
#
# === LIFSNN integ=exp seed=0 dt=5.0 T=50 ===
# Epoch 00: loss=0.3651, train_acc=89.77%, test_acc=93.44%, spike_rate=4.2931e-01, silent=0.571, active=0.429
# Epoch 01: loss=0.1546, train_acc=95.55%, test_acc=95.00%, spike_rate=4.2621e-01, silent=0.574, active=0.426
# Epoch 02: loss=0.1111, train_acc=96.80%, test_acc=96.41%, spike_rate=4.2378e-01, silent=0.576, active=0.424
# Epoch 03: loss=0.0854, train_acc=97.63%, test_acc=96.64%, spike_rate=4.2749e-01, silent=0.573, active=0.427
# Epoch 04: loss=0.0674, train_acc=98.17%, test_acc=96.56%, spike_rate=4.2319e-01, silent=0.577, active=0.423
# Epoch 05: loss=0.0550, train_acc=98.52%, test_acc=97.34%, spike_rate=4.2841e-01, silent=0.572, active=0.428
# Epoch 06: loss=0.0454, train_acc=98.77%, test_acc=97.34%, spike_rate=4.2672e-01, silent=0.573, active=0.427
# Epoch 07: loss=0.0357, train_acc=99.15%, test_acc=96.95%, spike_rate=4.3143e-01, silent=0.569, active=0.431
# Epoch 08: loss=0.0303, train_acc=99.26%, test_acc=97.34%, spike_rate=4.3212e-01, silent=0.568, active=0.432
# Epoch 09: loss=0.0253, train_acc=99.45%, test_acc=97.27%, spike_rate=4.2817e-01, silent=0.572, active=0.428
#
# === LIFSNN integ=exp seed=1 dt=5.0 T=50 ===
# Epoch 00: loss=0.3664, train_acc=89.74%, test_acc=93.05%, spike_rate=4.3703e-01, silent=0.563, active=0.437
# Epoch 01: loss=0.1588, train_acc=95.45%, test_acc=95.08%, spike_rate=4.3125e-01, silent=0.569, active=0.431
# Epoch 02: loss=0.1134, train_acc=96.76%, test_acc=95.55%, spike_rate=4.3324e-01, silent=0.567, active=0.433
# Epoch 03: loss=0.0873, train_acc=97.54%, test_acc=96.02%, spike_rate=4.3390e-01, silent=0.566, active=0.434
# Epoch 04: loss=0.0698, train_acc=98.10%, test_acc=96.56%, spike_rate=4.2807e-01, silent=0.572, active=0.428
# Epoch 05: loss=0.0550, train_acc=98.49%, test_acc=96.80%, spike_rate=4.3702e-01, silent=0.563, active=0.437
# Epoch 06: loss=0.0455, train_acc=98.82%, test_acc=97.27%, spike_rate=4.3333e-01, silent=0.567, active=0.433
# Epoch 07: loss=0.0377, train_acc=99.00%, test_acc=97.42%, spike_rate=4.3914e-01, silent=0.561, active=0.439
# Epoch 08: loss=0.0316, train_acc=99.22%, test_acc=97.27%, spike_rate=4.4020e-01, silent=0.560, active=0.440
# Epoch 09: loss=0.0256, train_acc=99.41%, test_acc=97.27%, spike_rate=4.3783e-01, silent=0.562, active=0.438
#
# === LIFSNN integ=exp seed=2 dt=5.0 T=50 ===
# Epoch 00: loss=0.3641, train_acc=89.94%, test_acc=92.89%, spike_rate=4.2218e-01, silent=0.578, active=0.422
# Epoch 01: loss=0.1550, train_acc=95.56%, test_acc=95.39%, spike_rate=4.2188e-01, silent=0.578, active=0.422
# Epoch 02: loss=0.1120, train_acc=96.82%, test_acc=96.80%, spike_rate=4.1609e-01, silent=0.584, active=0.416
# Epoch 03: loss=0.0855, train_acc=97.58%, test_acc=96.64%, spike_rate=4.2710e-01, silent=0.573, active=0.427
# Epoch 04: loss=0.0680, train_acc=98.11%, test_acc=96.72%, spike_rate=4.2374e-01, silent=0.576, active=0.424
# Epoch 05: loss=0.0554, train_acc=98.52%, test_acc=97.19%, spike_rate=4.2246e-01, silent=0.578, active=0.422
# Epoch 06: loss=0.0436, train_acc=98.89%, test_acc=97.19%, spike_rate=4.2916e-01, silent=0.571, active=0.429
# Epoch 07: loss=0.0364, train_acc=99.11%, test_acc=97.11%, spike_rate=4.2515e-01, silent=0.575, active=0.425
# Epoch 08: loss=0.0301, train_acc=99.29%, test_acc=97.42%, spike_rate=4.2604e-01, silent=0.574, active=0.426
# Epoch 09: loss=0.0255, train_acc=99.42%, test_acc=97.03%, spike_rate=4.1930e-01, silent=0.581, active=0.419
#
# === LIFSNN integ=exp seed=3 dt=5.0 T=50 ===
# Epoch 00: loss=0.3648, train_acc=89.72%, test_acc=92.89%, spike_rate=4.2366e-01, silent=0.576, active=0.424
# Epoch 01: loss=0.1568, train_acc=95.46%, test_acc=94.92%, spike_rate=4.2790e-01, silent=0.572, active=0.428
# Epoch 02: loss=0.1111, train_acc=96.84%, test_acc=95.86%, spike_rate=4.2655e-01, silent=0.573, active=0.427
# Epoch 03: loss=0.0862, train_acc=97.61%, test_acc=96.48%, spike_rate=4.3037e-01, silent=0.570, active=0.430
# Epoch 04: loss=0.0671, train_acc=98.12%, test_acc=97.27%, spike_rate=4.3223e-01, silent=0.568, active=0.432
# Epoch 05: loss=0.0557, train_acc=98.42%, test_acc=97.03%, spike_rate=4.2953e-01, silent=0.570, active=0.430
# Epoch 06: loss=0.0444, train_acc=98.80%, test_acc=97.34%, spike_rate=4.2704e-01, silent=0.573, active=0.427
# Epoch 07: loss=0.0373, train_acc=99.04%, test_acc=97.03%, spike_rate=4.4070e-01, silent=0.559, active=0.441
# Epoch 08: loss=0.0306, train_acc=99.29%, test_acc=97.34%, spike_rate=4.3408e-01, silent=0.566, active=0.434
# Epoch 09: loss=0.0257, train_acc=99.40%, test_acc=97.42%, spike_rate=4.4309e-01, silent=0.557, active=0.443
#
# === LIFSNN integ=exp seed=4 dt=5.0 T=50 ===
# Epoch 00: loss=0.3670, train_acc=89.76%, test_acc=93.28%, spike_rate=4.4793e-01, silent=0.552, active=0.448
# Epoch 01: loss=0.1599, train_acc=95.39%, test_acc=94.84%, spike_rate=4.4678e-01, silent=0.553, active=0.447
# Epoch 02: loss=0.1153, train_acc=96.72%, test_acc=96.09%, spike_rate=4.4251e-01, silent=0.557, active=0.443
# Epoch 03: loss=0.0891, train_acc=97.42%, test_acc=96.64%, spike_rate=4.4109e-01, silent=0.559, active=0.441
# Epoch 04: loss=0.0712, train_acc=97.99%, test_acc=96.88%, spike_rate=4.4114e-01, silent=0.559, active=0.441
# Epoch 05: loss=0.0575, train_acc=98.43%, test_acc=96.80%, spike_rate=4.4249e-01, silent=0.558, active=0.442
# Epoch 06: loss=0.0469, train_acc=98.73%, test_acc=97.03%, spike_rate=4.4439e-01, silent=0.556, active=0.444
# Epoch 07: loss=0.0389, train_acc=99.01%, test_acc=97.50%, spike_rate=4.4479e-01, silent=0.555, active=0.445
# Epoch 08: loss=0.0317, train_acc=99.25%, test_acc=97.34%, spike_rate=4.4716e-01, silent=0.553, active=0.447
# Epoch 09: loss=0.0259, train_acc=99.47%, test_acc=97.58%, spike_rate=4.5200e-01, silent=0.548, active=0.452
#     model integrator  seed   dt   T  final_acc  final_mean_spike_rate  \
# 0  LIFSNN      euler     0  5.0  50  67.359375               0.739574
# 1  LIFSNN      euler     1  5.0  50  65.796875               0.708221
# 2  LIFSNN      euler     2  5.0  50  69.765625               0.688680
# 3  LIFSNN      euler     3  5.0  50  73.984375               0.691897
# 4  LIFSNN      euler     4  5.0  50  65.156250               0.673109
# 5  LIFSNN        exp     0  5.0  50  97.000000               0.430748
# 6  LIFSNN        exp     1  5.0  50  97.093750               0.441342
# 7  LIFSNN        exp     2  5.0  50  97.234375               0.423535
# 8  LIFSNN        exp     3  5.0  50  97.046875               0.446466
# 9  LIFSNN        exp     4  5.0  50  97.015625               0.454024
#
#    final_silent_frac  final_active_frac
# 0           0.260426           0.739574
# 1           0.291779           0.708221
# 2           0.311320           0.688680
# 3           0.308103           0.691897
# 4           0.326891           0.673109
# 5           0.569252           0.430748
# 6           0.558658           0.441342
# 7           0.576465           0.423535
# 8           0.553534           0.446466
# 9           0.545976           0.454024
# Saved to dt5_stats_lif.csv

# %% [markdown]
# # 13. Исследование режима T=50, dt=5.0 с усреднением по времени

# %%
class IzhSNN(nn.Module):
    def __init__(self, integrator: str = 'euler', dt: float = 1.0, T: int = 50, readout: str = "mean"):
        super().__init__()
        self.T = int(T)
        self.readout = str(readout)

        self.fc1 = nn.Linear(28 * 28, 256, bias=False)
        self.neuron1 = neuron.IzhikevichNode(
            tau=2.0,
            v_c=0.8,
            a0=1.0,
            v_threshold=1.0,
            v_reset=0.0,
            v_rest=-0.1,
            w_rest=0.0,
            tau_w=2.0,
            a=0.02,
            b=0.2,
            surrogate_function=surrogate.Sigmoid(),
            integrator=integrator,
            dt=float(dt),
        )
        self.fc_out = nn.Linear(256, 10, bias=False)

    def forward(self, x: torch.Tensor, collect_stats: bool = False):
        x = x.view(x.size(0), -1)

        stats = SpikeStats() if collect_stats else None
        out_sum = None          # для mean/sum
        out_max = None          # для max

        for _ in range(self.T):
            x_t = encoder(x)        # encoder должен быть определён снаружи
            h = self.fc1(x_t)
            s = self.neuron1(h)

            if collect_stats:
                stats.update(s)

            out = self.fc_out(s)

            if self.readout == "max":
                out_max = out if out_max is None else torch.maximum(out_max, out)
            else:
                out_sum = out if out_sum is None else (out_sum + out)

        if self.readout == "max":
            out_accum = out_max
        elif self.readout == "sum":
            out_accum = out_sum
        elif self.readout == "mean":
            out_accum = out_sum / float(self.T)
        else:
            raise ValueError(f"Unknown readout={self.readout}. Use 'mean', 'sum', or 'max'.")

        return (out_accum, stats) if collect_stats else out_accum

# %%
class LIFSNN(nn.Module):
    def __init__(self, integrator: str = 'euler', dt: float = 1.0, T: int = 50, readout: str = "mean"):
        super().__init__()
        self.T = int(T)
        self.readout = str(readout)

        self.fc1 = nn.Linear(28 * 28, 256, bias=False)
        self.neuron1 = neuron.LIFNode(
            tau=2.0,
            decay_input=True,
            v_threshold=1.0,
            v_reset=0.0,
            surrogate_function=surrogate.Sigmoid(),
            integrator=integrator,   # 'euler' или 'exp'
            dt=float(dt),
        )
        self.fc_out = nn.Linear(256, 10, bias=False)

    def forward(self, x: torch.Tensor, collect_stats: bool = False):
        x = x.view(x.size(0), -1)

        stats = SpikeStats() if collect_stats else None
        out_sum = None
        out_max = None

        for _ in range(self.T):
            x_t = encoder(x)
            h = self.fc1(x_t)
            s = self.neuron1(h)

            if collect_stats:
                stats.update(s)

            out = self.fc_out(s)

            if self.readout == "max":
                out_max = out if out_max is None else torch.maximum(out_max, out)
            else:
                out_sum = out if out_sum is None else (out_sum + out)

        if self.readout == "max":
            out_accum = out_max
        elif self.readout == "sum":
            out_accum = out_sum
        elif self.readout == "mean":
            out_accum = out_sum / float(self.T)
        else:
            raise ValueError(f"Unknown readout={self.readout}. Use 'mean', 'sum', or 'max'.")

        return (out_accum, stats) if collect_stats else out_accum

# %%
def run_suite(model_cls, integrators, seeds, T, dt, EPOCHS, readout="mean"):
    rows = []
    for integ in integrators:
        for seed in seeds:
            print(f"\n=== {model_cls.__name__} integ={integ} seed={seed} dt={dt} T={T} readout={readout} ===")
            set_seed(seed)
            encoder.reset(dt=dt)

            model = model_cls(integrator=integ, T=T, dt=dt, readout=readout).to(DEVICE)
            optimizer = optim.Adam(model.parameters(), lr=LR)
            criterion = nn.CrossEntropyLoss()

            for epoch in range(EPOCHS):
                train_loss, train_acc = train_one_epoch(model, train_loader, optimizer, criterion)
                test_acc, test_stats = evaluate_with_stats(model, test_loader, max_batches=10)

                print(
                    f"Epoch {epoch:02d}: loss={train_loss:.4f}, train_acc={train_acc:.2f}%, "
                    f"test_acc={test_acc:.2f}%, "
                    f"spike_rate={test_stats['mean_spike_rate']:.4e}, "
                    f"silent={test_stats['silent_frac']:.3f}, active={test_stats['active_frac']:.3f}"
                )

            final_acc, final_stats = evaluate_with_stats(model, test_loader, max_batches=50)
            rows.append({
                "model": model_cls.__name__,
                "integrator": integ,
                "seed": seed,
                "dt": float(dt),
                "T": int(T),
                "readout": readout,
                "final_acc": float(final_acc),
                "final_mean_spike_rate": final_stats["mean_spike_rate"],
                "final_silent_frac": final_stats["silent_frac"],
                "final_active_frac": final_stats["active_frac"],
            })

    return pd.DataFrame(rows)


# -----------------------------
# Separate runners (as you asked)
# -----------------------------
def run_izh_dt5(dt=5.0, T=50, EPOCHS=10, SEEDS=(0,1,2,3,4), readout="mean"):
    return run_suite(IzhSNN, integrators=["euler", "symplectic"], seeds=list(SEEDS),
                     T=T, dt=dt, EPOCHS=EPOCHS, readout=readout)

def run_lif_dt5(dt=5.0, T=50, EPOCHS=10, SEEDS=(0,1,2,3,4), readout="mean"):
    return run_suite(LIFSNN, integrators=["euler", "exp"], seeds=list(SEEDS),
                     T=T, dt=dt, EPOCHS=EPOCHS, readout=readout)

# %%
dt = 5.0
T = 50
EPOCHS = 10
SEEDS = [0,1,2,3,4]

df_izh = run_izh_dt5(dt=dt, T=T, EPOCHS=EPOCHS, SEEDS=SEEDS, readout="mean")
display(df_izh)
df_izh.to_csv("dt5_izh_mean.csv", index=False)
# Out:
# === IzhSNN integ=euler seed=0 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 01: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 02: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 03: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 04: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 05: loss=2.3026, train_acc=9.86%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 06: loss=2.3026, train_acc=9.86%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 07: loss=2.3026, train_acc=9.86%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 08: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 09: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
#
# === IzhSNN integ=euler seed=1 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 01: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 02: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 03: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 04: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 05: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 06: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 07: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 08: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 09: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
#
# === IzhSNN integ=euler seed=2 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=2.3026, train_acc=9.86%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 01: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 02: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 03: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 04: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 05: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 06: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 07: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 08: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 09: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
#
# === IzhSNN integ=euler seed=3 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=2.3026, train_acc=9.86%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 01: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 02: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 03: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 04: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 05: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 06: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 07: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 08: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 09: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
#
# === IzhSNN integ=euler seed=4 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=2.3026, train_acc=9.89%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 01: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 02: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 03: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 04: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 05: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 06: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 07: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 08: loss=2.3026, train_acc=9.88%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
# Epoch 09: loss=2.3026, train_acc=9.87%, test_acc=8.52%, spike_rate=0.0000e+00, silent=1.000, active=0.000
#
# === IzhSNN integ=symplectic seed=0 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=2.2679, train_acc=18.20%, test_acc=19.30%, spike_rate=5.1197e-01, silent=0.488, active=0.512
# Epoch 01: loss=2.2417, train_acc=23.05%, test_acc=13.98%, spike_rate=5.1883e-01, silent=0.481, active=0.519
# Epoch 02: loss=2.2269, train_acc=22.91%, test_acc=31.02%, spike_rate=5.1892e-01, silent=0.481, active=0.519
# Epoch 03: loss=2.2041, train_acc=29.03%, test_acc=28.67%, spike_rate=5.2106e-01, silent=0.479, active=0.521
# Epoch 04: loss=2.1938, train_acc=29.94%, test_acc=33.52%, spike_rate=5.2086e-01, silent=0.479, active=0.521
# Epoch 05: loss=2.1743, train_acc=31.33%, test_acc=25.94%, spike_rate=5.2325e-01, silent=0.477, active=0.523
# Epoch 06: loss=2.1587, train_acc=34.21%, test_acc=33.91%, spike_rate=5.2354e-01, silent=0.476, active=0.524
# Epoch 07: loss=2.1420, train_acc=35.82%, test_acc=34.69%, spike_rate=5.2418e-01, silent=0.476, active=0.524
# Epoch 08: loss=2.1100, train_acc=37.64%, test_acc=26.17%, spike_rate=5.2560e-01, silent=0.474, active=0.526
# Epoch 09: loss=2.0930, train_acc=37.46%, test_acc=32.03%, spike_rate=5.2598e-01, silent=0.474, active=0.526
#
# === IzhSNN integ=symplectic seed=1 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=2.2666, train_acc=18.82%, test_acc=29.30%, spike_rate=5.1346e-01, silent=0.487, active=0.513
# Epoch 01: loss=2.2266, train_acc=25.45%, test_acc=34.61%, spike_rate=5.1834e-01, silent=0.482, active=0.518
# Epoch 02: loss=2.2089, train_acc=26.64%, test_acc=37.03%, spike_rate=5.1994e-01, silent=0.480, active=0.520
# Epoch 03: loss=2.1779, train_acc=30.40%, test_acc=34.45%, spike_rate=5.2423e-01, silent=0.476, active=0.524
# Epoch 04: loss=2.1402, train_acc=35.28%, test_acc=42.27%, spike_rate=5.2588e-01, silent=0.474, active=0.526
# Epoch 05: loss=2.1331, train_acc=36.67%, test_acc=31.56%, spike_rate=5.2535e-01, silent=0.475, active=0.525
# Epoch 06: loss=2.1120, train_acc=38.27%, test_acc=30.31%, spike_rate=5.2695e-01, silent=0.473, active=0.527
# Epoch 07: loss=2.0827, train_acc=41.12%, test_acc=41.48%, spike_rate=5.2756e-01, silent=0.472, active=0.528
# Epoch 08: loss=2.0648, train_acc=40.81%, test_acc=43.28%, spike_rate=5.2817e-01, silent=0.472, active=0.528
# Epoch 09: loss=2.0439, train_acc=43.02%, test_acc=41.64%, spike_rate=5.2876e-01, silent=0.471, active=0.529
#
# === IzhSNN integ=symplectic seed=2 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=2.2637, train_acc=18.35%, test_acc=32.27%, spike_rate=5.1316e-01, silent=0.487, active=0.513
# Epoch 01: loss=2.2415, train_acc=23.12%, test_acc=23.83%, spike_rate=5.1788e-01, silent=0.482, active=0.518
# Epoch 02: loss=2.2230, train_acc=25.47%, test_acc=33.83%, spike_rate=5.2138e-01, silent=0.479, active=0.521
# Epoch 03: loss=2.2076, train_acc=26.86%, test_acc=20.70%, spike_rate=5.2464e-01, silent=0.475, active=0.525
# Epoch 04: loss=2.1957, train_acc=31.03%, test_acc=35.00%, spike_rate=5.2472e-01, silent=0.475, active=0.525
# Epoch 05: loss=2.1794, train_acc=32.21%, test_acc=36.09%, spike_rate=5.2503e-01, silent=0.475, active=0.525
# Epoch 06: loss=2.1560, train_acc=35.73%, test_acc=37.19%, spike_rate=5.2653e-01, silent=0.473, active=0.527
# Epoch 07: loss=2.1353, train_acc=37.05%, test_acc=49.45%, spike_rate=5.2719e-01, silent=0.473, active=0.527
# Epoch 08: loss=2.1095, train_acc=39.48%, test_acc=46.02%, spike_rate=5.2900e-01, silent=0.471, active=0.529
# Epoch 09: loss=2.0842, train_acc=40.41%, test_acc=42.89%, spike_rate=5.3027e-01, silent=0.470, active=0.530
#
# === IzhSNN integ=symplectic seed=3 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=2.2758, train_acc=16.81%, test_acc=13.52%, spike_rate=5.0846e-01, silent=0.492, active=0.508
# Epoch 01: loss=2.2443, train_acc=21.26%, test_acc=19.45%, spike_rate=5.1424e-01, silent=0.486, active=0.514
# Epoch 02: loss=2.2189, train_acc=25.37%, test_acc=18.20%, spike_rate=5.1706e-01, silent=0.483, active=0.517
# Epoch 03: loss=2.1869, train_acc=28.17%, test_acc=26.48%, spike_rate=5.1879e-01, silent=0.481, active=0.519
# Epoch 04: loss=2.1777, train_acc=30.84%, test_acc=32.42%, spike_rate=5.2035e-01, silent=0.480, active=0.520
# Epoch 05: loss=2.1572, train_acc=32.50%, test_acc=29.14%, spike_rate=5.2105e-01, silent=0.479, active=0.521
# Epoch 06: loss=2.1255, train_acc=35.73%, test_acc=41.95%, spike_rate=5.2317e-01, silent=0.477, active=0.523
# Epoch 07: loss=2.0891, train_acc=39.12%, test_acc=36.95%, spike_rate=5.2451e-01, silent=0.475, active=0.525
# Epoch 08: loss=2.0671, train_acc=39.72%, test_acc=42.50%, spike_rate=5.2558e-01, silent=0.474, active=0.526
# Epoch 09: loss=2.0375, train_acc=43.34%, test_acc=41.25%, spike_rate=5.2782e-01, silent=0.472, active=0.528
#
# === IzhSNN integ=symplectic seed=4 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=2.2696, train_acc=17.51%, test_acc=27.11%, spike_rate=5.1043e-01, silent=0.490, active=0.510
# Epoch 01: loss=2.2481, train_acc=21.36%, test_acc=28.20%, spike_rate=5.1616e-01, silent=0.484, active=0.516
# Epoch 02: loss=2.2257, train_acc=24.24%, test_acc=25.78%, spike_rate=5.1824e-01, silent=0.482, active=0.518
# Epoch 03: loss=2.1995, train_acc=29.34%, test_acc=34.22%, spike_rate=5.2143e-01, silent=0.479, active=0.521
# Epoch 04: loss=2.1787, train_acc=30.75%, test_acc=39.14%, spike_rate=5.2515e-01, silent=0.475, active=0.525
# Epoch 05: loss=2.1502, train_acc=34.50%, test_acc=36.17%, spike_rate=5.2604e-01, silent=0.474, active=0.526
# Epoch 06: loss=2.1339, train_acc=36.35%, test_acc=42.34%, spike_rate=5.2696e-01, silent=0.473, active=0.527
# Epoch 07: loss=2.1282, train_acc=35.85%, test_acc=38.98%, spike_rate=5.2730e-01, silent=0.473, active=0.527
# Epoch 08: loss=2.0967, train_acc=40.58%, test_acc=45.00%, spike_rate=5.2848e-01, silent=0.472, active=0.528
# Epoch 09: loss=2.0612, train_acc=43.10%, test_acc=44.69%, spike_rate=5.2973e-01, silent=0.470, active=0.530
#     model  integrator  seed   dt   T readout  final_acc  \
# 0  IzhSNN       euler     0  5.0  50    mean   9.468750
# 1  IzhSNN       euler     1  5.0  50    mean   9.468750
# 2  IzhSNN       euler     2  5.0  50    mean   9.468750
# 3  IzhSNN       euler     3  5.0  50    mean   9.468750
# 4  IzhSNN       euler     4  5.0  50    mean   9.468750
# 5  IzhSNN  symplectic     0  5.0  50    mean  33.125000
# 6  IzhSNN  symplectic     1  5.0  50    mean  39.921875
# 7  IzhSNN  symplectic     2  5.0  50    mean  43.781250
# 8  IzhSNN  symplectic     3  5.0  50    mean  41.203125
# 9  IzhSNN  symplectic     4  5.0  50    mean  45.593750
#
#    final_mean_spike_rate  final_silent_frac  final_active_frac
# 0               0.000000           1.000000           0.000000
# 1               0.000000           1.000000           0.000000
# 2               0.000000           1.000000           0.000000
# 3               0.000000           1.000000           0.000000
# 4               0.000000           1.000000           0.000000
# 5               0.526737           0.473263           0.526737
# 6               0.529574           0.470426           0.529574
# 7               0.530993           0.469007           0.530993
# 8               0.528481           0.471519           0.528481
# 9               0.530385           0.469615           0.530385

# %%
dt = 5.0
T = 50
EPOCHS = 10
SEEDS = [0,1,2,3,4]

df_lif = run_lif_dt5(dt=dt, T=T, EPOCHS=EPOCHS, SEEDS=SEEDS, readout="mean")
display(df_lif)
df_lif.to_csv("dt5_lif_mean.csv", index=False)
# Out:
# === LIFSNN integ=euler seed=0 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=1.1087, train_acc=73.24%, test_acc=77.34%, spike_rate=5.0704e-01, silent=0.493, active=0.507
# Epoch 01: loss=0.7256, train_acc=80.81%, test_acc=80.47%, spike_rate=5.2418e-01, silent=0.476, active=0.524
# Epoch 02: loss=0.6804, train_acc=81.21%, test_acc=79.06%, spike_rate=5.5563e-01, silent=0.444, active=0.556
# Epoch 03: loss=0.6620, train_acc=81.08%, test_acc=78.67%, spike_rate=5.6913e-01, silent=0.431, active=0.569
# Epoch 04: loss=0.6427, train_acc=81.44%, test_acc=77.03%, spike_rate=5.8843e-01, silent=0.412, active=0.588
# Epoch 05: loss=0.7195, train_acc=79.30%, test_acc=72.19%, spike_rate=5.9255e-01, silent=0.407, active=0.593
# Epoch 06: loss=0.7693, train_acc=76.03%, test_acc=74.22%, spike_rate=5.9983e-01, silent=0.400, active=0.600
# Epoch 07: loss=0.7466, train_acc=77.68%, test_acc=76.80%, spike_rate=6.1008e-01, silent=0.390, active=0.610
# Epoch 08: loss=0.7468, train_acc=76.33%, test_acc=73.12%, spike_rate=6.0356e-01, silent=0.396, active=0.604
# Epoch 09: loss=0.7505, train_acc=76.46%, test_acc=73.05%, spike_rate=6.1723e-01, silent=0.383, active=0.617
#
# === LIFSNN integ=euler seed=1 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=1.1179, train_acc=73.30%, test_acc=76.72%, spike_rate=4.8834e-01, silent=0.512, active=0.488
# Epoch 01: loss=0.7176, train_acc=81.73%, test_acc=77.11%, spike_rate=5.2588e-01, silent=0.474, active=0.526
# Epoch 02: loss=0.7077, train_acc=80.81%, test_acc=75.70%, spike_rate=5.4526e-01, silent=0.455, active=0.545
# Epoch 03: loss=0.7216, train_acc=79.25%, test_acc=78.52%, spike_rate=5.6185e-01, silent=0.438, active=0.562
# Epoch 04: loss=0.7444, train_acc=78.20%, test_acc=76.72%, spike_rate=5.6661e-01, silent=0.433, active=0.567
# Epoch 05: loss=0.7260, train_acc=78.62%, test_acc=76.88%, spike_rate=5.7609e-01, silent=0.424, active=0.576
# Epoch 06: loss=0.7198, train_acc=78.52%, test_acc=75.78%, spike_rate=5.8437e-01, silent=0.416, active=0.584
# Epoch 07: loss=0.7292, train_acc=77.15%, test_acc=74.45%, spike_rate=5.9187e-01, silent=0.408, active=0.592
# Epoch 08: loss=0.7092, train_acc=77.81%, test_acc=77.42%, spike_rate=5.9814e-01, silent=0.402, active=0.598
# Epoch 09: loss=0.6877, train_acc=78.93%, test_acc=77.66%, spike_rate=6.1005e-01, silent=0.390, active=0.610
#
# === LIFSNN integ=euler seed=2 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=1.1788, train_acc=71.15%, test_acc=74.61%, spike_rate=4.9816e-01, silent=0.502, active=0.498
# Epoch 01: loss=0.7491, train_acc=79.87%, test_acc=76.95%, spike_rate=5.3965e-01, silent=0.460, active=0.540
# Epoch 02: loss=0.7086, train_acc=80.63%, test_acc=79.14%, spike_rate=5.6010e-01, silent=0.440, active=0.560
# Epoch 03: loss=0.7203, train_acc=79.63%, test_acc=75.78%, spike_rate=5.9618e-01, silent=0.404, active=0.596
# Epoch 04: loss=0.7766, train_acc=76.91%, test_acc=71.56%, spike_rate=5.9047e-01, silent=0.410, active=0.590
# Epoch 05: loss=0.7972, train_acc=75.85%, test_acc=71.33%, spike_rate=6.0797e-01, silent=0.392, active=0.608
# Epoch 06: loss=0.7354, train_acc=77.48%, test_acc=74.22%, spike_rate=6.1674e-01, silent=0.383, active=0.617
# Epoch 07: loss=0.7726, train_acc=76.50%, test_acc=74.77%, spike_rate=6.1798e-01, silent=0.382, active=0.618
# Epoch 08: loss=0.7454, train_acc=76.83%, test_acc=75.23%, spike_rate=6.1914e-01, silent=0.381, active=0.619
# Epoch 09: loss=0.7653, train_acc=76.47%, test_acc=72.27%, spike_rate=6.1902e-01, silent=0.381, active=0.619
#
# === LIFSNN integ=euler seed=3 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=1.1591, train_acc=73.26%, test_acc=73.44%, spike_rate=5.1892e-01, silent=0.481, active=0.519
# Epoch 01: loss=0.8687, train_acc=77.07%, test_acc=73.44%, spike_rate=5.3736e-01, silent=0.463, active=0.537
# Epoch 02: loss=0.7909, train_acc=77.62%, test_acc=75.08%, spike_rate=5.5002e-01, silent=0.450, active=0.550
# Epoch 03: loss=0.7957, train_acc=76.75%, test_acc=73.75%, spike_rate=5.7532e-01, silent=0.425, active=0.575
# Epoch 04: loss=0.7506, train_acc=77.50%, test_acc=76.72%, spike_rate=5.7924e-01, silent=0.421, active=0.579
# Epoch 05: loss=0.7376, train_acc=77.64%, test_acc=75.00%, spike_rate=5.9513e-01, silent=0.405, active=0.595
# Epoch 06: loss=0.7518, train_acc=76.82%, test_acc=75.70%, spike_rate=6.0490e-01, silent=0.395, active=0.605
# Epoch 07: loss=0.8038, train_acc=75.15%, test_acc=73.05%, spike_rate=6.0341e-01, silent=0.397, active=0.603
# Epoch 08: loss=0.8113, train_acc=74.53%, test_acc=72.58%, spike_rate=6.1538e-01, silent=0.385, active=0.615
# Epoch 09: loss=0.8422, train_acc=73.24%, test_acc=70.94%, spike_rate=6.2090e-01, silent=0.379, active=0.621
#
# === LIFSNN integ=euler seed=4 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=1.1686, train_acc=71.76%, test_acc=76.80%, spike_rate=4.9777e-01, silent=0.502, active=0.498
# Epoch 01: loss=0.7709, train_acc=79.47%, test_acc=76.72%, spike_rate=5.2586e-01, silent=0.474, active=0.526
# Epoch 02: loss=0.7143, train_acc=80.02%, test_acc=78.05%, spike_rate=5.4661e-01, silent=0.453, active=0.547
# Epoch 03: loss=0.7401, train_acc=78.88%, test_acc=77.11%, spike_rate=5.7393e-01, silent=0.426, active=0.574
# Epoch 04: loss=0.7557, train_acc=77.87%, test_acc=74.14%, spike_rate=5.9256e-01, silent=0.407, active=0.593
# Epoch 05: loss=0.7939, train_acc=76.51%, test_acc=75.55%, spike_rate=6.0947e-01, silent=0.391, active=0.609
# Epoch 06: loss=0.7549, train_acc=77.53%, test_acc=75.16%, spike_rate=6.0900e-01, silent=0.391, active=0.609
# Epoch 07: loss=0.7959, train_acc=74.95%, test_acc=72.58%, spike_rate=6.1797e-01, silent=0.382, active=0.618
# Epoch 08: loss=0.7884, train_acc=75.45%, test_acc=74.14%, spike_rate=6.2100e-01, silent=0.379, active=0.621
# Epoch 09: loss=0.7781, train_acc=75.62%, test_acc=70.86%, spike_rate=6.3174e-01, silent=0.368, active=0.632
#
# === LIFSNN integ=exp seed=0 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=0.3614, train_acc=89.88%, test_acc=93.59%, spike_rate=4.3137e-01, silent=0.569, active=0.431
# Epoch 01: loss=0.1507, train_acc=95.68%, test_acc=95.16%, spike_rate=4.2714e-01, silent=0.573, active=0.427
# Epoch 02: loss=0.1059, train_acc=97.01%, test_acc=96.56%, spike_rate=4.2488e-01, silent=0.575, active=0.425
# Epoch 03: loss=0.0799, train_acc=97.77%, test_acc=96.64%, spike_rate=4.2776e-01, silent=0.572, active=0.428
# Epoch 04: loss=0.0617, train_acc=98.32%, test_acc=96.88%, spike_rate=4.2553e-01, silent=0.574, active=0.426
# Epoch 05: loss=0.0494, train_acc=98.72%, test_acc=97.73%, spike_rate=4.2689e-01, silent=0.573, active=0.427
# Epoch 06: loss=0.0394, train_acc=99.03%, test_acc=97.11%, spike_rate=4.2522e-01, silent=0.575, active=0.425
# Epoch 07: loss=0.0297, train_acc=99.35%, test_acc=97.66%, spike_rate=4.2839e-01, silent=0.572, active=0.428
# Epoch 08: loss=0.0236, train_acc=99.52%, test_acc=97.50%, spike_rate=4.3022e-01, silent=0.570, active=0.430
# Epoch 09: loss=0.0185, train_acc=99.71%, test_acc=97.27%, spike_rate=4.2882e-01, silent=0.571, active=0.429
#
# === LIFSNN integ=exp seed=1 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=0.3620, train_acc=89.87%, test_acc=92.89%, spike_rate=4.3630e-01, silent=0.564, active=0.436
# Epoch 01: loss=0.1535, train_acc=95.57%, test_acc=95.31%, spike_rate=4.2954e-01, silent=0.570, active=0.430
# Epoch 02: loss=0.1074, train_acc=96.97%, test_acc=95.86%, spike_rate=4.2857e-01, silent=0.571, active=0.429
# Epoch 03: loss=0.0815, train_acc=97.75%, test_acc=96.72%, spike_rate=4.3134e-01, silent=0.569, active=0.431
# Epoch 04: loss=0.0627, train_acc=98.33%, test_acc=96.56%, spike_rate=4.2470e-01, silent=0.575, active=0.425
# Epoch 05: loss=0.0486, train_acc=98.71%, test_acc=97.03%, spike_rate=4.2686e-01, silent=0.573, active=0.427
# Epoch 06: loss=0.0386, train_acc=99.08%, test_acc=97.34%, spike_rate=4.2722e-01, silent=0.573, active=0.427
# Epoch 07: loss=0.0298, train_acc=99.33%, test_acc=97.58%, spike_rate=4.3071e-01, silent=0.569, active=0.431
# Epoch 08: loss=0.0239, train_acc=99.51%, test_acc=97.50%, spike_rate=4.3167e-01, silent=0.568, active=0.432
# Epoch 09: loss=0.0189, train_acc=99.66%, test_acc=97.42%, spike_rate=4.3630e-01, silent=0.564, active=0.436
#
# === LIFSNN integ=exp seed=2 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=0.3606, train_acc=90.11%, test_acc=93.12%, spike_rate=4.2056e-01, silent=0.579, active=0.421
# Epoch 01: loss=0.1505, train_acc=95.67%, test_acc=95.70%, spike_rate=4.1794e-01, silent=0.582, active=0.418
# Epoch 02: loss=0.1068, train_acc=97.00%, test_acc=96.48%, spike_rate=4.1252e-01, silent=0.587, active=0.413
# Epoch 03: loss=0.0794, train_acc=97.82%, test_acc=96.72%, spike_rate=4.1982e-01, silent=0.580, active=0.420
# Epoch 04: loss=0.0623, train_acc=98.28%, test_acc=96.88%, spike_rate=4.1857e-01, silent=0.581, active=0.419
# Epoch 05: loss=0.0489, train_acc=98.75%, test_acc=96.88%, spike_rate=4.1673e-01, silent=0.583, active=0.417
# Epoch 06: loss=0.0380, train_acc=99.04%, test_acc=97.27%, spike_rate=4.2298e-01, silent=0.577, active=0.423
# Epoch 07: loss=0.0302, train_acc=99.32%, test_acc=97.19%, spike_rate=4.1956e-01, silent=0.580, active=0.420
# Epoch 08: loss=0.0237, train_acc=99.55%, test_acc=97.50%, spike_rate=4.2270e-01, silent=0.577, active=0.423
# Epoch 09: loss=0.0190, train_acc=99.66%, test_acc=97.34%, spike_rate=4.1913e-01, silent=0.581, active=0.419
#
# === LIFSNN integ=exp seed=3 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=0.3612, train_acc=89.81%, test_acc=92.81%, spike_rate=4.2301e-01, silent=0.577, active=0.423
# Epoch 01: loss=0.1529, train_acc=95.57%, test_acc=95.31%, spike_rate=4.2627e-01, silent=0.574, active=0.426
# Epoch 02: loss=0.1063, train_acc=96.99%, test_acc=96.17%, spike_rate=4.3014e-01, silent=0.570, active=0.430
# Epoch 03: loss=0.0807, train_acc=97.84%, test_acc=96.88%, spike_rate=4.2981e-01, silent=0.570, active=0.430
# Epoch 04: loss=0.0622, train_acc=98.33%, test_acc=97.27%, spike_rate=4.3439e-01, silent=0.566, active=0.434
# Epoch 05: loss=0.0496, train_acc=98.68%, test_acc=97.50%, spike_rate=4.3060e-01, silent=0.569, active=0.431
# Epoch 06: loss=0.0387, train_acc=99.05%, test_acc=97.66%, spike_rate=4.3139e-01, silent=0.569, active=0.431
# Epoch 07: loss=0.0310, train_acc=99.32%, test_acc=97.27%, spike_rate=4.3532e-01, silent=0.565, active=0.435
# Epoch 08: loss=0.0237, train_acc=99.55%, test_acc=97.73%, spike_rate=4.3517e-01, silent=0.565, active=0.435
# Epoch 09: loss=0.0190, train_acc=99.66%, test_acc=97.66%, spike_rate=4.3682e-01, silent=0.563, active=0.437
#
# === LIFSNN integ=exp seed=4 dt=5.0 T=50 readout=mean ===
# Epoch 00: loss=0.3645, train_acc=89.85%, test_acc=93.12%, spike_rate=4.4077e-01, silent=0.559, active=0.441
# Epoch 01: loss=0.1548, train_acc=95.57%, test_acc=95.00%, spike_rate=4.4218e-01, silent=0.558, active=0.442
# Epoch 02: loss=0.1091, train_acc=96.91%, test_acc=96.48%, spike_rate=4.3862e-01, silent=0.561, active=0.439
# Epoch 03: loss=0.0827, train_acc=97.67%, test_acc=96.64%, spike_rate=4.3796e-01, silent=0.562, active=0.438
# Epoch 04: loss=0.0637, train_acc=98.23%, test_acc=96.95%, spike_rate=4.3823e-01, silent=0.562, active=0.438
# Epoch 05: loss=0.0513, train_acc=98.63%, test_acc=96.95%, spike_rate=4.4039e-01, silent=0.560, active=0.440
# Epoch 06: loss=0.0398, train_acc=99.05%, test_acc=96.80%, spike_rate=4.4236e-01, silent=0.558, active=0.442
# Epoch 07: loss=0.0312, train_acc=99.31%, test_acc=96.64%, spike_rate=4.4690e-01, silent=0.553, active=0.447
# Epoch 08: loss=0.0253, train_acc=99.47%, test_acc=97.50%, spike_rate=4.4823e-01, silent=0.552, active=0.448
# Epoch 09: loss=0.0193, train_acc=99.66%, test_acc=97.34%, spike_rate=4.5110e-01, silent=0.549, active=0.451
#     model integrator  seed   dt   T readout  final_acc  final_mean_spike_rate  \
# 0  LIFSNN      euler     0  5.0  50    mean  75.156250               0.620407
# 1  LIFSNN      euler     1  5.0  50    mean  77.546875               0.613187
# 2  LIFSNN      euler     2  5.0  50    mean  73.250000               0.621442
# 3  LIFSNN      euler     3  5.0  50    mean  72.546875               0.623688
# 4  LIFSNN      euler     4  5.0  50    mean  72.718750               0.635236
# 5  LIFSNN        exp     0  5.0  50    mean  96.953125               0.431061
# 6  LIFSNN        exp     1  5.0  50    mean  97.203125               0.440122
# 7  LIFSNN        exp     2  5.0  50    mean  97.046875               0.422635
# 8  LIFSNN        exp     3  5.0  50    mean  97.328125               0.440020
# 9  LIFSNN        exp     4  5.0  50    mean  97.281250               0.452969
#
#    final_silent_frac  final_active_frac
# 0           0.379593           0.620407
# 1           0.386813           0.613187
# 2           0.378558           0.621442
# 3           0.376312           0.623688
# 4           0.364764           0.635236
# 5           0.568939           0.431061
# 6           0.559878           0.440122
# 7           0.577365           0.422635
# 8           0.559980           0.440020
# 9           0.547031           0.452969

# %% [markdown]
# # Сеть с STDP

# %%
# rstdp_mnist_spikingjelly.py
# LIF-only SNN + spike-count argmax + R-STDP (on W_out) + optional teacher forcing on output current
# Integrator sweep: "euler" vs "exp"
#
# Requirements: spikingjelly, torch, torchvision

import os
import math
import random
from dataclasses import dataclass
from typing import Optional, Tuple, Dict, Any, List

import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

from spikingjelly.activation_based import neuron, functional, surrogate


# -----------------------------
# Repro / device
# -----------------------------
def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


DEVICE = "cuda" if torch.cuda.is_available() else "cpu"


# -----------------------------
# Simple Poisson encoder wrapper
# -----------------------------
class PoissonEncoderWrapper:
    """
    Bernoulli(p=x) per pixel per step, expects x in [0,1].
    dt stored only for API compatibility.
    """
    def __init__(self):
        self._dt = 1.0

    def reset(self, dt: float = 1.0):
        self._dt = float(dt)

    def __call__(self, x: torch.Tensor) -> torch.Tensor:
        return (torch.rand_like(x) < x).to(x.dtype)


encoder = PoissonEncoderWrapper()


# -----------------------------
# Spike stats
# -----------------------------
@dataclass
class SpikeStats:
    total_spikes: float = 0.0
    total_sites: int = 0
    silent_sites: int = 0
    active_sites: int = 0

    def update(self, s_2d: torch.Tensor):
        with torch.no_grad():
            B, N = s_2d.shape
            sites = B * N
            active = (s_2d > 0).sum().item()
            silent = sites - active
            self.total_sites += int(sites)
            self.active_sites += int(active)
            self.silent_sites += int(silent)
            self.total_spikes += float(active)

    def merge_(self, other: "SpikeStats"):
        self.total_spikes += other.total_spikes
        self.total_sites += other.total_sites
        self.silent_sites += other.silent_sites
        self.active_sites += other.active_sites

    def summary(self) -> Dict[str, float]:
        denom = max(1, self.total_sites)
        active_frac = self.active_sites / denom
        silent_frac = self.silent_sites / denom
        mean_spike_rate = self.total_spikes / denom
        return {
            "mean_spike_rate": float(mean_spike_rate),
            "silent_frac": float(silent_frac),
            "active_frac": float(active_frac),
        }


def _spikes_to_2d(s: torch.Tensor) -> torch.Tensor:
    if s.dim() == 1:
        return s.unsqueeze(0)
    return s.view(s.size(0), -1)


# -----------------------------
# Model: LIF-only SNN
# -----------------------------
class LIF_RSTDP_SNN(nn.Module):
    def __init__(
        self,
        integrator: str = "euler",
        dt: float = 0.1,
        T: int = 200,
        n_hidden: int = 256,
        n_classes: int = 10,
        v_th: float = 0.3,
        tau: float = 2.0,
        in_gain: float = 5.0,
        out_gain: float = 5.0,
        decay_input: bool = False,
    ):
        super().__init__()
        self.T = int(T)
        self.n_hidden = int(n_hidden)
        self.n_classes = int(n_classes)
        self.in_gain = float(in_gain)
        self.out_gain = float(out_gain)

        self.fc_in = nn.Linear(28 * 28, self.n_hidden, bias=False)
        self.neuron_h = neuron.LIFNode(
            tau=float(tau),
            decay_input=bool(decay_input),
            v_threshold=float(v_th),
            v_reset=0.0,
            surrogate_function=surrogate.Sigmoid(),  # INSTANCE (callable)
            integrator=integrator,
            dt=float(dt),
        )

        self.fc_out = nn.Linear(self.n_hidden, self.n_classes, bias=False)
        self.neuron_o = neuron.LIFNode(
            tau=float(tau),
            decay_input=bool(decay_input),
            v_threshold=float(v_th),
            v_reset=0.0,
            surrogate_function=surrogate.Sigmoid(),
            integrator=integrator,
            dt=float(dt),
        )

        nn.init.kaiming_uniform_(self.fc_in.weight, a=math.sqrt(5))
        nn.init.kaiming_uniform_(self.fc_out.weight, a=math.sqrt(5))

    @torch.no_grad()
    def forward_collect(
        self,
        x: torch.Tensor,
        y: Optional[torch.Tensor] = None,
        teach_current: float = 0.0,
        collect_stats: bool = True,
    ):
        """
        Returns:
          h_count: [B,H] spike counts
          o_count: [B,C] spike counts
          stats_h, stats_o: SpikeStats for hidden and output separately
          no_spike_out_frac: fraction of samples where output never spiked
        """
        x = x.view(x.size(0), -1)

        stats_h = SpikeStats() if collect_stats else SpikeStats()
        stats_o = SpikeStats() if collect_stats else SpikeStats()

        B = x.size(0)
        h_count = torch.zeros((B, self.n_hidden), device=x.device, dtype=torch.float32)
        o_count = torch.zeros((B, self.n_classes), device=x.device, dtype=torch.float32)

        for _ in range(self.T):
            x_t = encoder(x)  # [B,784] 0/1

            h_cur = self.fc_in(x_t) * self.in_gain
            s_h = self.neuron_h(h_cur)  # [B,H]

            o_cur = self.fc_out(s_h) * self.out_gain  # [B,C]

            # teacher forcing only when y is given
            if (y is not None) and (teach_current > 0.0):
                o_cur = o_cur.clone()
                o_cur[torch.arange(B, device=x.device), y] += float(teach_current)

            s_o = self.neuron_o(o_cur)  # [B,C]

            # --- hard WTA on output spikes (per-step) ---
            # if any output spikes in a sample, keep only the spike of the max-current neuron
            spike_any = (s_o > 0).any(dim=1)  # [B]
            if spike_any.any():
                winner = o_cur.argmax(dim=1)  # [B]
                s_o_wta = torch.zeros_like(s_o)
                s_o_wta[spike_any, winner[spike_any]] = 1.0
                s_o = s_o_wta
            # ------------------------------------------


            h_count += s_h.float()
            o_count += s_o.float()

            if collect_stats:
                stats_h.update(_spikes_to_2d(s_h))
                stats_o.update(_spikes_to_2d(s_o))

        no_spike_out_frac = float((o_count.sum(dim=1) == 0).float().mean().item())
        return h_count, o_count, stats_h, stats_o, no_spike_out_frac


# -----------------------------
# R-STDP update on W_out only
# -----------------------------
@torch.no_grad()
def rstdp_update_w_out(
    model: LIF_RSTDP_SNN,
    h_count: torch.Tensor,   # [B,H]
    o_count: torch.Tensor,   # [B,C]
    y: torch.Tensor,         # [B]
    lr_wout: float,
    reward_mode: str = "pm1",    # "pm1" or "onehot"
    w_clip: Optional[float] = 5.0,
    l2_decay: float = 0.0,
):
    W = model.fc_out.weight  # [C,H]
    B = h_count.size(0)

    pre = h_count / max(1.0, float(model.T))   # [B,H]
    post = o_count / max(1.0, float(model.T))  # [B,C]

    if reward_mode == "pm1":
        # winner by spike-count
        winner = o_count.argmax(dim=1)  # [B]
        r = torch.where(winner == y,
                        torch.ones_like(y, dtype=torch.float32),
                        -torch.ones_like(y, dtype=torch.float32)).to(W.device)  # [B]

        # dW only for winner row: dW[w,:] += mean_i r_i * pre_i
        dW = torch.zeros_like(W)
        for c in range(model.n_classes):
            mask = (winner == c)
            if mask.any():
                dW[c] = (r[mask][:, None] * pre[mask]).mean(dim=0)

    elif reward_mode == "onehot":
        y_oh = torch.zeros((B, model.n_classes), device=W.device, dtype=torch.float32)
        y_oh.scatter_(1, y.view(-1, 1), 1.0)
        prob = torch.softmax(o_count, dim=1).detach()
        err = (y_oh - prob)  # [B,C]
        dW = (err[:, :, None] * pre[:, None, :]).mean(dim=0)

    else:
        raise ValueError(f"Unknown reward_mode: {reward_mode}")

    if l2_decay > 0:
        W.mul_(1.0 - float(l2_decay))

    W.add_(float(lr_wout) * dW)

    if w_clip is not None:
        W.clamp_(-float(w_clip), float(w_clip))


# -----------------------------
# Metrics
# -----------------------------
@torch.no_grad()
def spikecount_pseudo_ce(o_count: torch.Tensor, y: torch.Tensor) -> float:
    return float(torch.nn.functional.cross_entropy(o_count, y).item())


@torch.no_grad()
def evaluate_spikecount(
    model: LIF_RSTDP_SNN,
    loader: DataLoader,
    max_batches: Optional[int] = 50,
) -> Tuple[float, Dict[str, float], Dict[str, float], float]:
    model.eval()
    agg_h = SpikeStats()
    agg_o = SpikeStats()
    no_spike_out_sum = 0.0
    batches = 0

    correct = 0
    total = 0

    for bi, (x, y) in enumerate(loader):
        if max_batches is not None and bi >= max_batches:
            break

        x = x.to(DEVICE, non_blocking=True)
        y = y.to(DEVICE, non_blocking=True)

        functional.reset_net(model)
        h_count, o_count, stats_h, stats_o, no_spike_out_frac = model.forward_collect(
            x, y=None, teach_current=0.0, collect_stats=True
        )

        pred = o_count.argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.numel()

        agg_h.merge_(stats_h)
        agg_o.merge_(stats_o)
        no_spike_out_sum += no_spike_out_frac
        batches += 1

    acc = 100.0 * correct / max(1, total)
    return acc, agg_h.summary(), agg_o.summary(), (no_spike_out_sum / max(1, batches))


@torch.no_grad()
def train_one_epoch_rstdp(
    model: LIF_RSTDP_SNN,
    loader: DataLoader,
    lr_wout: float,
    reward_mode: str = "pm1",
    teach_current: float = 0.0,
    max_batches: Optional[int] = 1000,
    w_clip: Optional[float] = 5.0,
    l2_decay: float = 0.0,
) -> Tuple[float, float, Dict[str, float], Dict[str, float], float]:
    model.train()
    agg_h = SpikeStats()
    agg_o = SpikeStats()
    no_spike_out_sum = 0.0
    batches = 0

    correct = 0
    total = 0
    loss_sum = 0.0
    seen = 0

    for bi, (x, y) in enumerate(loader):
        if max_batches is not None and bi >= max_batches:
            break

        x = x.to(DEVICE, non_blocking=True)
        y = y.to(DEVICE, non_blocking=True)

        functional.reset_net(model)
        h_count, o_count, stats_h, stats_o, no_spike_out_frac = model.forward_collect(
            x, y=y, teach_current=teach_current, collect_stats=True
        )

        loss_sum += spikecount_pseudo_ce(o_count, y)
        seen += 1

        pred = o_count.argmax(dim=1)
        correct += (pred == y).sum().item()
        total += y.numel()

        agg_h.merge_(stats_h)
        agg_o.merge_(stats_o)
        no_spike_out_sum += no_spike_out_frac
        batches += 1

        rstdp_update_w_out(
            model=model,
            h_count=h_count,
            o_count=o_count,
            y=y,
            lr_wout=lr_wout,
            reward_mode=reward_mode,
            w_clip=w_clip,
            l2_decay=l2_decay,
        )

    train_acc = 100.0 * correct / max(1, total)
    pseudo_ce = loss_sum / max(1, seen)
    return pseudo_ce, train_acc, agg_h.summary(), agg_o.summary(), (no_spike_out_sum / max(1, batches))


# -----------------------------
# Experiment runner
# -----------------------------
def run_rstdp_experiment(
    integrator: str,
    seed: int,
    dt: float,
    T: int,
    epochs: int,
    lr_wout: float,
    reward_mode: str,
    teach_i0: float,
    teach_decay: float,
    train_loader: DataLoader,
    test_loader: DataLoader,
    max_train_batches: Optional[int] = 1000,
    max_test_batches: Optional[int] = 50,
    model_kwargs: Optional[Dict[str, Any]] = None,
) -> Dict[str, Any]:
    print(f"\n=== LIF R-STDP integ={integrator} seed={seed} dt={dt} T={T} ===")

    set_seed(seed)
    encoder.reset(dt=dt)

    model_kwargs = model_kwargs or {}
    model = LIF_RSTDP_SNN(integrator=integrator, dt=dt, T=T, **model_kwargs).to(DEVICE)

    # quick debug forward
    x, y = next(iter(train_loader))
    x = x.to(DEVICE); y = y.to(DEVICE)
    functional.reset_net(model)
    h_count, o_count, sh, so, noz = model.forward_collect(x, y=y, teach_current=teach_i0, collect_stats=True)
    print(
        "debug:",
        "h_count mean", float(h_count.mean().item()),
        "o_count mean", float(o_count.mean().item()),
        "H", sh.summary(),
        "O", so.summary(),
        "no_spike_out", f"{noz:.3f}"
    )

    teach_i = float(teach_i0)

    for ep in range(epochs):
        pseudo_ce, train_acc, train_h, train_o, train_noz = train_one_epoch_rstdp(
            model=model,
            loader=train_loader,
            lr_wout=lr_wout,
            reward_mode=reward_mode,
            teach_current=teach_i,
            max_batches=max_train_batches,
            w_clip=5.0,
            l2_decay=0.0,
        )

        test_acc, test_h, test_o, test_noz = evaluate_spikecount(
            model=model,
            loader=test_loader,
            max_batches=max_test_batches,
        )

        print(
            f"Epoch {ep:02d}: teachI={teach_i:.3f} pseudoCE={pseudo_ce:.4f} "
            f"train_acc={train_acc:.2f}% test_acc={test_acc:.2f}% | "
            f"H_rate={test_h['mean_spike_rate']:.4f} O_rate={test_o['mean_spike_rate']:.4f} "
            f"no_spike_out={test_noz:.3f}"
        )

        teach_i *= float(teach_decay)

    final_acc, final_h, final_o, final_noz = evaluate_spikecount(model, test_loader, max_batches=None)
    return {
        "integrator": integrator,
        "seed": seed,
        "dt": dt,
        "T": T,
        "final_acc": final_acc,
        "final_H_mean_spike_rate": final_h["mean_spike_rate"],
        "final_O_mean_spike_rate": final_o["mean_spike_rate"],
        "final_no_spike_out_frac": final_noz,
    }

# %%
def main():
    print(f"DEVICE = {DEVICE}")

    # ---- experiment settings ----
    DT = 0.5
    T = 200
    EPOCHS = 5
    SEEDS = [0]
    INTEGRATORS = ["euler", "exp"]
    LR_WOUT = 5e-2
    REWARD_MODE = "pm1"

    # teacher forcing (output current injection)
    TEACH_I0 = 1.0      # start injection
    TEACH_DECAY = 0.95  # per-epoch decay

    # speed
    MAX_TRAIN_BATCHES = 1000
    MAX_TEST_BATCHES = 50
    BATCH_TRAIN = 64
    BATCH_TEST = 256

    # data
    tfm = transforms.Compose([transforms.ToTensor()])
    root = os.environ.get("DATA", "./data")
    train_ds = datasets.MNIST(root=root, train=True, download=True, transform=tfm)
    test_ds = datasets.MNIST(root=root, train=False, download=True, transform=tfm)

    train_loader = DataLoader(
        train_ds, batch_size=BATCH_TRAIN, shuffle=True,
        num_workers=0, pin_memory=(DEVICE == "cuda"), drop_last=True
    )
    test_loader = DataLoader(
        test_ds, batch_size=BATCH_TEST, shuffle=False,
        num_workers=0, pin_memory=(DEVICE == "cuda")
    )

    with torch.no_grad():
        x0, _ = next(iter(train_loader))
        print(f"Encoder mean spike prob (over pixels, per step) ~ {float(x0.mean().item()):.6f}")

    # model hyperparams (keep fixed across integrators for fairness)
    model_kwargs = dict(
        v_th=0.3,
        tau=2.0,
        in_gain=5.0,
        out_gain=5.0,
        decay_input=False,
    )

    results = []
    for integ in INTEGRATORS:
        for seed in SEEDS:
            res = run_rstdp_experiment(
                integrator=integ,
                seed=seed,
                dt=DT,
                T=T,
                epochs=EPOCHS,
                lr_wout=LR_WOUT,
                reward_mode=REWARD_MODE,
                teach_i0=TEACH_I0,
                teach_decay=TEACH_DECAY,
                train_loader=train_loader,
                test_loader=test_loader,
                max_train_batches=MAX_TRAIN_BATCHES,
                max_test_batches=MAX_TEST_BATCHES,
                model_kwargs=model_kwargs,
            )
            results.append(res)

    print("\nResults:")
    for r in results:
        print(r)


if __name__ == "__main__":
    main()
# Out:
# DEVICE = cuda
# Encoder mean spike prob (over pixels, per step) ~ 0.126272
#
# === LIF R-STDP integ=euler seed=0 dt=0.5 T=200 ===
# debug: h_count mean 57.05804443359375 o_count mean 19.9609375 H {'mean_spike_rate': 0.28529022216796873, 'silent_frac': 0.7147097778320313, 'active_frac': 0.28529022216796873} O {'mean_spike_rate': 0.0998046875, 'silent_frac': 0.9001953125, 'active_frac': 0.0998046875} no_spike_out 0.000
# Epoch 00: teachI=1.000 pseudoCE=17.2660 train_acc=28.87% test_acc=29.54% | H_rate=0.2874 O_rate=0.0245 no_spike_out=0.623
# Epoch 01: teachI=0.950 pseudoCE=14.6078 train_acc=29.13% test_acc=29.49% | H_rate=0.2874 O_rate=0.0244 no_spike_out=0.621
# Epoch 02: teachI=0.902 pseudoCE=14.6735 train_acc=29.19% test_acc=29.48% | H_rate=0.2874 O_rate=0.0245 no_spike_out=0.616
# Epoch 03: teachI=0.857 pseudoCE=14.4002 train_acc=29.16% test_acc=29.49% | H_rate=0.2874 O_rate=0.0235 no_spike_out=0.630
# Epoch 04: teachI=0.815 pseudoCE=14.2216 train_acc=29.15% test_acc=29.50% | H_rate=0.2874 O_rate=0.0245 no_spike_out=0.616
#
# === LIF R-STDP integ=exp seed=0 dt=0.5 T=200 ===
# debug: h_count mean 33.56976318359375 o_count mean 18.515625 H {'mean_spike_rate': 0.16784881591796874, 'silent_frac': 0.8321511840820313, 'active_frac': 0.16784881591796874} O {'mean_spike_rate': 0.092578125, 'silent_frac': 0.907421875, 'active_frac': 0.092578125} no_spike_out 0.000
# Epoch 00: teachI=1.000 pseudoCE=39.2013 train_acc=51.63% test_acc=57.05% | H_rate=0.1685 O_rate=0.0997 no_spike_out=0.000
# Epoch 01: teachI=0.950 pseudoCE=41.9494 train_acc=58.64% test_acc=59.67% | H_rate=0.1685 O_rate=0.1000 no_spike_out=0.000
# Epoch 02: teachI=0.902 pseudoCE=40.6023 train_acc=59.63% test_acc=59.74% | H_rate=0.1685 O_rate=0.1000 no_spike_out=0.000
# Epoch 03: teachI=0.857 pseudoCE=39.7454 train_acc=59.81% test_acc=59.99% | H_rate=0.1685 O_rate=0.1000 no_spike_out=0.000
# Epoch 04: teachI=0.815 pseudoCE=39.1139 train_acc=59.93% test_acc=60.02% | H_rate=0.1685 O_rate=0.1000 no_spike_out=0.000
#
# Results:
# {'integrator': 'euler', 'seed': 0, 'dt': 0.5, 'T': 200, 'final_acc': 29.6, 'final_H_mean_spike_rate': 0.287364853515625, 'final_O_mean_spike_rate': 0.0245313, 'final_no_spike_out_frac': 0.61396484375}
# {'integrator': 'exp', 'seed': 0, 'dt': 0.5, 'T': 200, 'final_acc': 60.16, 'final_H_mean_spike_rate': 0.168538197265625, 'final_O_mean_spike_rate': 0.09999895, 'final_no_spike_out_frac': 0.0}

# %%
def main():
    print(f"DEVICE = {DEVICE}")

    # ---- experiment settings ----
    DT = 0.1
    T = 200
    EPOCHS = 5
    SEEDS = [0]
    INTEGRATORS = ["euler", "exp"]
    LR_WOUT = 5e-2
    REWARD_MODE = "pm1"

    # teacher forcing (output current injection)
    TEACH_I0 = 1.0      # start injection
    TEACH_DECAY = 0.95  # per-epoch decay

    # speed
    MAX_TRAIN_BATCHES = 1000
    MAX_TEST_BATCHES = 50
    BATCH_TRAIN = 64
    BATCH_TEST = 256

    # data
    tfm = transforms.Compose([transforms.ToTensor()])
    root = os.environ.get("DATA", "./data")
    train_ds = datasets.MNIST(root=root, train=True, download=True, transform=tfm)
    test_ds = datasets.MNIST(root=root, train=False, download=True, transform=tfm)

    train_loader = DataLoader(
        train_ds, batch_size=BATCH_TRAIN, shuffle=True,
        num_workers=0, pin_memory=(DEVICE == "cuda"), drop_last=True
    )
    test_loader = DataLoader(
        test_ds, batch_size=BATCH_TEST, shuffle=False,
        num_workers=0, pin_memory=(DEVICE == "cuda")
    )

    with torch.no_grad():
        x0, _ = next(iter(train_loader))
        print(f"Encoder mean spike prob (over pixels, per step) ~ {float(x0.mean().item()):.6f}")

    # model hyperparams (keep fixed across integrators for fairness)
    model_kwargs = dict(
        v_th=0.3,
        tau=2.0,
        in_gain=5.0,
        out_gain=5.0,
        decay_input=False,
    )

    results = []
    for integ in INTEGRATORS:
        for seed in SEEDS:
            res = run_rstdp_experiment(
                integrator=integ,
                seed=seed,
                dt=DT,
                T=T,
                epochs=EPOCHS,
                lr_wout=LR_WOUT,
                reward_mode=REWARD_MODE,
                teach_i0=TEACH_I0,
                teach_decay=TEACH_DECAY,
                train_loader=train_loader,
                test_loader=test_loader,
                max_train_batches=MAX_TRAIN_BATCHES,
                max_test_batches=MAX_TEST_BATCHES,
                model_kwargs=model_kwargs,
            )
            results.append(res)

    print("\nResults:")
    for r in results:
        print(r)


if __name__ == "__main__":
    main()
# Out:
# DEVICE = cuda
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.24MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.72MB/s]
# Encoder mean spike prob (over pixels, per step) ~ 0.127302
#
# === LIF R-STDP integ=euler seed=0 dt=0.1 T=200 ===
# debug: h_count mean 18.20306396484375 o_count mean 10.83750057220459 H {'mean_spike_rate': 0.09101531982421875, 'silent_frac': 0.9089846801757813, 'active_frac': 0.09101531982421875} O {'mean_spike_rate': 0.0541875, 'silent_frac': 0.9458125, 'active_frac': 0.0541875} no_spike_out 0.000
# Epoch 00: teachI=1.000 pseudoCE=10.6410 train_acc=79.52% test_acc=78.86% | H_rate=0.0916 O_rate=0.0997 no_spike_out=0.000
# Epoch 01: teachI=0.950 pseudoCE=11.0424 train_acc=78.65% test_acc=78.68% | H_rate=0.0916 O_rate=0.0997 no_spike_out=0.000
# Epoch 02: teachI=0.902 pseudoCE=9.4640 train_acc=79.48% test_acc=79.24% | H_rate=0.0916 O_rate=0.0997 no_spike_out=0.000
# Epoch 03: teachI=0.857 pseudoCE=8.2619 train_acc=80.62% test_acc=79.31% | H_rate=0.0916 O_rate=0.0997 no_spike_out=0.000
# Epoch 04: teachI=0.815 pseudoCE=7.2264 train_acc=81.83% test_acc=78.80% | H_rate=0.0916 O_rate=0.0997 no_spike_out=0.000
#
# === LIF R-STDP integ=exp seed=0 dt=0.1 T=200 ===
# debug: h_count mean 8.55059814453125 o_count mean 3.4515626430511475 H {'mean_spike_rate': 0.04275299072265625, 'silent_frac': 0.9572470092773437, 'active_frac': 0.04275299072265625} O {'mean_spike_rate': 0.0172578125, 'silent_frac': 0.9827421875, 'active_frac': 0.0172578125} no_spike_out 0.000
# Epoch 00: teachI=1.000 pseudoCE=5.5293 train_acc=82.52% test_acc=78.13% | H_rate=0.0430 O_rate=0.0990 no_spike_out=0.000
# Epoch 01: teachI=0.950 pseudoCE=6.9692 train_acc=79.53% test_acc=78.23% | H_rate=0.0430 O_rate=0.0990 no_spike_out=0.000
# Epoch 02: teachI=0.902 pseudoCE=6.8037 train_acc=79.84% test_acc=77.89% | H_rate=0.0430 O_rate=0.0990 no_spike_out=0.000
# Epoch 03: teachI=0.857 pseudoCE=6.0459 train_acc=80.85% test_acc=77.76% | H_rate=0.0430 O_rate=0.0990 no_spike_out=0.000
# Epoch 04: teachI=0.815 pseudoCE=4.9782 train_acc=82.97% test_acc=77.27% | H_rate=0.0430 O_rate=0.0990 no_spike_out=0.000
#
# Results:
# {'integrator': 'euler', 'seed': 0, 'dt': 0.1, 'T': 200, 'final_acc': 78.97, 'final_H_mean_spike_rate': 0.09158528515625, 'final_O_mean_spike_rate': 0.09968755, 'final_no_spike_out_frac': 0.0}
# {'integrator': 'exp', 'seed': 0, 'dt': 0.1, 'T': 200, 'final_acc': 77.2, 'final_H_mean_spike_rate': 0.042970626953125, 'final_O_mean_spike_rate': 0.09898745, 'final_no_spike_out_frac': 0.0}

# %%
def main():
    print(f"DEVICE = {DEVICE}")

    # ---- experiment settings ----
    DT = 0.05
    T = 200
    EPOCHS = 5
    SEEDS = [0]
    INTEGRATORS = ["euler", "exp"]
    LR_WOUT = 5e-2
    REWARD_MODE = "pm1"

    # teacher forcing (output current injection)
    TEACH_I0 = 1.0      # start injection
    TEACH_DECAY = 0.95  # per-epoch decay

    # speed
    MAX_TRAIN_BATCHES = 1000
    MAX_TEST_BATCHES = 50
    BATCH_TRAIN = 64
    BATCH_TEST = 256

    # data
    tfm = transforms.Compose([transforms.ToTensor()])
    root = os.environ.get("DATA", "./data")
    train_ds = datasets.MNIST(root=root, train=True, download=True, transform=tfm)
    test_ds = datasets.MNIST(root=root, train=False, download=True, transform=tfm)

    train_loader = DataLoader(
        train_ds, batch_size=BATCH_TRAIN, shuffle=True,
        num_workers=0, pin_memory=(DEVICE == "cuda"), drop_last=True
    )
    test_loader = DataLoader(
        test_ds, batch_size=BATCH_TEST, shuffle=False,
        num_workers=0, pin_memory=(DEVICE == "cuda")
    )

    with torch.no_grad():
        x0, _ = next(iter(train_loader))
        print(f"Encoder mean spike prob (over pixels, per step) ~ {float(x0.mean().item()):.6f}")

    # model hyperparams (keep fixed across integrators for fairness)
    model_kwargs = dict(
        v_th=0.3,
        tau=2.0,
        in_gain=5.0,
        out_gain=5.0,
        decay_input=False,
    )

    results = []
    for integ in INTEGRATORS:
        for seed in SEEDS:
            res = run_rstdp_experiment(
                integrator=integ,
                seed=seed,
                dt=DT,
                T=T,
                epochs=EPOCHS,
                lr_wout=LR_WOUT,
                reward_mode=REWARD_MODE,
                teach_i0=TEACH_I0,
                teach_decay=TEACH_DECAY,
                train_loader=train_loader,
                test_loader=test_loader,
                max_train_batches=MAX_TRAIN_BATCHES,
                max_test_batches=MAX_TEST_BATCHES,
                model_kwargs=model_kwargs,
            )
            results.append(res)

    print("\nResults:")
    for r in results:
        print(r)


if __name__ == "__main__":
    main()
# Out:
# DEVICE = cuda
# Encoder mean spike prob (over pixels, per step) ~ 0.126272
#
# === LIF R-STDP integ=euler seed=0 dt=0.05 T=200 ===
# debug: h_count mean 9.7490234375 o_count mean 4.589062690734863 H {'mean_spike_rate': 0.0487451171875, 'silent_frac': 0.9512548828125, 'active_frac': 0.0487451171875} O {'mean_spike_rate': 0.0229453125, 'silent_frac': 0.9770546875, 'active_frac': 0.0229453125} no_spike_out 0.000
# Epoch 00: teachI=1.000 pseudoCE=5.8131 train_acc=82.43% test_acc=78.43% | H_rate=0.0490 O_rate=0.0991 no_spike_out=0.000
# Epoch 01: teachI=0.950 pseudoCE=7.2474 train_acc=79.40% test_acc=78.33% | H_rate=0.0490 O_rate=0.0991 no_spike_out=0.000
# Epoch 02: teachI=0.902 pseudoCE=7.0326 train_acc=79.47% test_acc=78.34% | H_rate=0.0490 O_rate=0.0991 no_spike_out=0.000
# Epoch 03: teachI=0.857 pseudoCE=6.1239 train_acc=80.61% test_acc=77.93% | H_rate=0.0490 O_rate=0.0991 no_spike_out=0.000
# Epoch 04: teachI=0.815 pseudoCE=4.8941 train_acc=83.14% test_acc=78.03% | H_rate=0.0490 O_rate=0.0991 no_spike_out=0.000
#
# === LIF R-STDP integ=exp seed=0 dt=0.05 T=200 ===
# debug: h_count mean 4.376708984375 o_count mean 1.3328125476837158 H {'mean_spike_rate': 0.021883544921875, 'silent_frac': 0.978116455078125, 'active_frac': 0.021883544921875} O {'mean_spike_rate': 0.0066640625, 'silent_frac': 0.9933359375, 'active_frac': 0.0066640625} no_spike_out 0.000
# Epoch 00: teachI=1.000 pseudoCE=2.2512 train_acc=88.17% test_acc=77.08% | H_rate=0.0220 O_rate=0.0954 no_spike_out=0.000
# Epoch 01: teachI=0.950 pseudoCE=3.8982 train_acc=81.26% test_acc=77.25% | H_rate=0.0220 O_rate=0.0966 no_spike_out=0.000
# Epoch 02: teachI=0.902 pseudoCE=3.7762 train_acc=82.09% test_acc=77.67% | H_rate=0.0220 O_rate=0.0968 no_spike_out=0.000
# Epoch 03: teachI=0.857 pseudoCE=3.3135 train_acc=84.13% test_acc=76.51% | H_rate=0.0220 O_rate=0.0969 no_spike_out=0.000
# Epoch 04: teachI=0.815 pseudoCE=2.6427 train_acc=86.94% test_acc=75.00% | H_rate=0.0220 O_rate=0.0969 no_spike_out=0.000
#
# Results:
# {'integrator': 'euler', 'seed': 0, 'dt': 0.05, 'T': 200, 'final_acc': 78.4, 'final_H_mean_spike_rate': 0.049039048828125, 'final_O_mean_spike_rate': 0.0990652, 'final_no_spike_out_frac': 0.0}
# {'integrator': 'exp', 'seed': 0, 'dt': 0.05, 'T': 200, 'final_acc': 74.9, 'final_H_mean_spike_rate': 0.02199023046875, 'final_O_mean_spike_rate': 0.09692515, 'final_no_spike_out_frac': 0.0}

# %%
def main():
    print(f"DEVICE = {DEVICE}")

    # ---- experiment settings ----
    DT = 0.01
    T = 200
    EPOCHS = 5
    SEEDS = [0]
    INTEGRATORS = ["euler", "exp"]
    LR_WOUT = 5e-2
    REWARD_MODE = "pm1"

    # teacher forcing (output current injection)
    TEACH_I0 = 1.0      # start injection
    TEACH_DECAY = 0.95  # per-epoch decay

    # speed
    MAX_TRAIN_BATCHES = 1000
    MAX_TEST_BATCHES = 50
    BATCH_TRAIN = 64
    BATCH_TEST = 256

    # data
    tfm = transforms.Compose([transforms.ToTensor()])
    root = os.environ.get("DATA", "./data")
    train_ds = datasets.MNIST(root=root, train=True, download=True, transform=tfm)
    test_ds = datasets.MNIST(root=root, train=False, download=True, transform=tfm)

    train_loader = DataLoader(
        train_ds, batch_size=BATCH_TRAIN, shuffle=True,
        num_workers=0, pin_memory=(DEVICE == "cuda"), drop_last=True
    )
    test_loader = DataLoader(
        test_ds, batch_size=BATCH_TEST, shuffle=False,
        num_workers=0, pin_memory=(DEVICE == "cuda")
    )

    with torch.no_grad():
        x0, _ = next(iter(train_loader))
        print(f"Encoder mean spike prob (over pixels, per step) ~ {float(x0.mean().item()):.6f}")

    # model hyperparams (keep fixed across integrators for fairness)
    model_kwargs = dict(
        v_th=0.3,
        tau=2.0,
        in_gain=5.0,
        out_gain=5.0,
        decay_input=False,
    )

    results = []
    for integ in INTEGRATORS:
        for seed in SEEDS:
            res = run_rstdp_experiment(
                integrator=integ,
                seed=seed,
                dt=DT,
                T=T,
                epochs=EPOCHS,
                lr_wout=LR_WOUT,
                reward_mode=REWARD_MODE,
                teach_i0=TEACH_I0,
                teach_decay=TEACH_DECAY,
                train_loader=train_loader,
                test_loader=test_loader,
                max_train_batches=MAX_TRAIN_BATCHES,
                max_test_batches=MAX_TEST_BATCHES,
                model_kwargs=model_kwargs,
            )
            results.append(res)

    print("\nResults:")
    for r in results:
        print(r)


if __name__ == "__main__":
    main()
# Out:
# DEVICE = cuda
# Encoder mean spike prob (over pixels, per step) ~ 0.126272
#
# === LIF R-STDP integ=euler seed=0 dt=0.01 T=200 ===
# debug: h_count mean 1.918701171875 o_count mean 0.5625 H {'mean_spike_rate': 0.009593505859375, 'silent_frac': 0.990406494140625, 'active_frac': 0.009593505859375} O {'mean_spike_rate': 0.0028125, 'silent_frac': 0.9971875, 'active_frac': 0.0028125} no_spike_out 0.000
# Epoch 00: teachI=1.000 pseudoCE=0.3799 train_acc=95.68% test_acc=70.26% | H_rate=0.0097 O_rate=0.0684 no_spike_out=0.000
# Epoch 01: teachI=0.950 pseudoCE=1.0719 train_acc=88.76% test_acc=73.35% | H_rate=0.0097 O_rate=0.0726 no_spike_out=0.000
# Epoch 02: teachI=0.902 pseudoCE=1.4360 train_acc=85.62% test_acc=74.35% | H_rate=0.0097 O_rate=0.0745 no_spike_out=0.000
# Epoch 03: teachI=0.857 pseudoCE=1.3956 train_acc=86.55% test_acc=73.79% | H_rate=0.0097 O_rate=0.0757 no_spike_out=0.000
# Epoch 04: teachI=0.815 pseudoCE=1.1304 train_acc=88.75% test_acc=73.44% | H_rate=0.0097 O_rate=0.0761 no_spike_out=0.000
#
# === LIF R-STDP integ=exp seed=0 dt=0.01 T=200 ===
# debug: h_count mean 0.7630615234375 o_count mean 0.20156250894069672 H {'mean_spike_rate': 0.0038153076171875, 'silent_frac': 0.9961846923828125, 'active_frac': 0.0038153076171875} O {'mean_spike_rate': 0.0010078125, 'silent_frac': 0.9989921875, 'active_frac': 0.0010078125} no_spike_out 0.000
# Epoch 00: teachI=1.000 pseudoCE=0.1803 train_acc=97.78% test_acc=41.43% | H_rate=0.0038 O_rate=0.0166 no_spike_out=0.000
# Epoch 01: teachI=0.950 pseudoCE=0.3127 train_acc=91.45% test_acc=54.27% | H_rate=0.0038 O_rate=0.0271 no_spike_out=0.000
# Epoch 02: teachI=0.902 pseudoCE=0.4802 train_acc=88.40% test_acc=61.07% | H_rate=0.0038 O_rate=0.0332 no_spike_out=0.000
# Epoch 03: teachI=0.857 pseudoCE=0.6390 train_acc=85.72% test_acc=63.04% | H_rate=0.0038 O_rate=0.0370 no_spike_out=0.000
# Epoch 04: teachI=0.815 pseudoCE=0.7842 train_acc=83.72% test_acc=66.17% | H_rate=0.0038 O_rate=0.0397 no_spike_out=0.000
#
# Results:
# {'integrator': 'euler', 'seed': 0, 'dt': 0.01, 'T': 200, 'final_acc': 73.23, 'final_H_mean_spike_rate': 0.009653728515625, 'final_O_mean_spike_rate': 0.0761465, 'final_no_spike_out_frac': 0.0}
# {'integrator': 'exp', 'seed': 0, 'dt': 0.01, 'T': 200, 'final_acc': 66.43, 'final_H_mean_spike_rate': 0.0038276875, 'final_O_mean_spike_rate': 0.0396898, 'final_no_spike_out_frac': 0.0}

# %%
def main():
    print(f"DEVICE = {DEVICE}")

    # ---- experiment settings ----
    DT = 0.005
    T = 200
    EPOCHS = 5
    SEEDS = [0]
    INTEGRATORS = ["euler", "exp"]
    LR_WOUT = 5e-2
    REWARD_MODE = "pm1"

    # teacher forcing (output current injection)
    TEACH_I0 = 1.0      # start injection
    TEACH_DECAY = 0.95  # per-epoch decay

    # speed
    MAX_TRAIN_BATCHES = 1000
    MAX_TEST_BATCHES = 50
    BATCH_TRAIN = 64
    BATCH_TEST = 256

    # data
    tfm = transforms.Compose([transforms.ToTensor()])
    root = os.environ.get("DATA", "./data")
    train_ds = datasets.MNIST(root=root, train=True, download=True, transform=tfm)
    test_ds = datasets.MNIST(root=root, train=False, download=True, transform=tfm)

    train_loader = DataLoader(
        train_ds, batch_size=BATCH_TRAIN, shuffle=True,
        num_workers=0, pin_memory=(DEVICE == "cuda"), drop_last=True
    )
    test_loader = DataLoader(
        test_ds, batch_size=BATCH_TEST, shuffle=False,
        num_workers=0, pin_memory=(DEVICE == "cuda")
    )

    with torch.no_grad():
        x0, _ = next(iter(train_loader))
        print(f"Encoder mean spike prob (over pixels, per step) ~ {float(x0.mean().item()):.6f}")

    # model hyperparams (keep fixed across integrators for fairness)
    model_kwargs = dict(
        v_th=0.3,
        tau=2.0,
        in_gain=5.0,
        out_gain=5.0,
        decay_input=False,
    )

    results = []
    for integ in INTEGRATORS:
        for seed in SEEDS:
            res = run_rstdp_experiment(
                integrator=integ,
                seed=seed,
                dt=DT,
                T=T,
                epochs=EPOCHS,
                lr_wout=LR_WOUT,
                reward_mode=REWARD_MODE,
                teach_i0=TEACH_I0,
                teach_decay=TEACH_DECAY,
                train_loader=train_loader,
                test_loader=test_loader,
                max_train_batches=MAX_TRAIN_BATCHES,
                max_test_batches=MAX_TEST_BATCHES,
                model_kwargs=model_kwargs,
            )
            results.append(res)

    print("\nResults:")
    for r in results:
        print(r)


if __name__ == "__main__":
    main()
# Out:
# DEVICE = cuda
# Encoder mean spike prob (over pixels, per step) ~ 0.126272
#
# === LIF R-STDP integ=euler seed=0 dt=0.005 T=200 ===
# debug: h_count mean 0.8660888671875 o_count mean 0.27656251192092896 H {'mean_spike_rate': 0.0043304443359375, 'silent_frac': 0.9956695556640625, 'active_frac': 0.0043304443359375} O {'mean_spike_rate': 0.0013828125, 'silent_frac': 0.9986171875, 'active_frac': 0.0013828125} no_spike_out 0.000
# Epoch 00: teachI=1.000 pseudoCE=0.1216 train_acc=98.12% test_acc=44.67% | H_rate=0.0044 O_rate=0.0211 no_spike_out=0.000
# Epoch 01: teachI=0.950 pseudoCE=0.3111 train_acc=92.22% test_acc=58.22% | H_rate=0.0044 O_rate=0.0325 no_spike_out=0.000
# Epoch 02: teachI=0.902 pseudoCE=0.4613 train_acc=89.62% test_acc=63.75% | H_rate=0.0044 O_rate=0.0388 no_spike_out=0.000
# Epoch 03: teachI=0.857 pseudoCE=0.6441 train_acc=86.91% test_acc=66.31% | H_rate=0.0044 O_rate=0.0426 no_spike_out=0.000
# Epoch 04: teachI=0.815 pseudoCE=0.8026 train_acc=84.57% test_acc=67.95% | H_rate=0.0044 O_rate=0.0451 no_spike_out=0.000
#
# === LIF R-STDP integ=exp seed=0 dt=0.005 T=200 ===
# debug: h_count mean 0.29827880859375 o_count mean 0.10000000149011612 H {'mean_spike_rate': 0.00149139404296875, 'silent_frac': 0.9985086059570313, 'active_frac': 0.00149139404296875} O {'mean_spike_rate': 0.0005, 'silent_frac': 0.9995, 'active_frac': 0.0005} no_spike_out 0.000
# Epoch 00: teachI=1.000 pseudoCE=1.4145 train_acc=96.43% test_acc=9.46% | H_rate=0.0015 O_rate=0.0000 no_spike_out=0.979
# Epoch 01: teachI=0.950 pseudoCE=1.2790 train_acc=81.20% test_acc=15.52% | H_rate=0.0015 O_rate=0.0006 no_spike_out=0.630
# Epoch 02: teachI=0.902 pseudoCE=1.1579 train_acc=75.65% test_acc=21.80% | H_rate=0.0015 O_rate=0.0018 no_spike_out=0.300
# Epoch 03: teachI=0.857 pseudoCE=1.0807 train_acc=74.05% test_acc=26.78% | H_rate=0.0015 O_rate=0.0029 no_spike_out=0.155
# Epoch 04: teachI=0.815 pseudoCE=1.0742 train_acc=71.33% test_acc=30.43% | H_rate=0.0015 O_rate=0.0038 no_spike_out=0.087
#
# Results:
# {'integrator': 'euler', 'seed': 0, 'dt': 0.005, 'T': 200, 'final_acc': 67.78, 'final_H_mean_spike_rate': 0.004355583984375, 'final_O_mean_spike_rate': 0.04505395, 'final_no_spike_out_frac': 0.0}
# {'integrator': 'exp', 'seed': 0, 'dt': 0.005, 'T': 200, 'final_acc': 30.59, 'final_H_mean_spike_rate': 0.001493865234375, 'final_O_mean_spike_rate': 0.00383835, 'final_no_spike_out_frac': 0.0880859375}

# %%
def main():
    print(f"DEVICE = {DEVICE}")

    # ---- experiment settings ----
    DT = 0.005
    T = 2000
    EPOCHS = 5
    SEEDS = [0]
    INTEGRATORS = ["euler", "exp"]
    LR_WOUT = 5e-2
    REWARD_MODE = "pm1"

    # teacher forcing (output current injection)
    TEACH_I0 = 1.0      # start injection
    TEACH_DECAY = 0.95  # per-epoch decay

    # speed
    MAX_TRAIN_BATCHES = 1000
    MAX_TEST_BATCHES = 50
    BATCH_TRAIN = 64
    BATCH_TEST = 256

    # data
    tfm = transforms.Compose([transforms.ToTensor()])
    root = os.environ.get("DATA", "./data")
    train_ds = datasets.MNIST(root=root, train=True, download=True, transform=tfm)
    test_ds = datasets.MNIST(root=root, train=False, download=True, transform=tfm)

    train_loader = DataLoader(
        train_ds, batch_size=BATCH_TRAIN, shuffle=True,
        num_workers=0, pin_memory=(DEVICE == "cuda"), drop_last=True
    )
    test_loader = DataLoader(
        test_ds, batch_size=BATCH_TEST, shuffle=False,
        num_workers=0, pin_memory=(DEVICE == "cuda")
    )

    with torch.no_grad():
        x0, _ = next(iter(train_loader))
        print(f"Encoder mean spike prob (over pixels, per step) ~ {float(x0.mean().item()):.6f}")

    # model hyperparams (keep fixed across integrators for fairness)
    model_kwargs = dict(
        v_th=0.3,
        tau=2.0,
        in_gain=5.0,
        out_gain=5.0,
        decay_input=False,
    )

    results = []
    for integ in INTEGRATORS:
        for seed in SEEDS:
            res = run_rstdp_experiment(
                integrator=integ,
                seed=seed,
                dt=DT,
                T=T,
                epochs=EPOCHS,
                lr_wout=LR_WOUT,
                reward_mode=REWARD_MODE,
                teach_i0=TEACH_I0,
                teach_decay=TEACH_DECAY,
                train_loader=train_loader,
                test_loader=test_loader,
                max_train_batches=MAX_TRAIN_BATCHES,
                max_test_batches=MAX_TEST_BATCHES,
                model_kwargs=model_kwargs,
            )
            results.append(res)

    print("\nResults:")
    for r in results:
        print(r)


if __name__ == "__main__":
    main()
# Out:
# DEVICE = cuda
# Encoder mean spike prob (over pixels, per step) ~ 0.126272
#
# === LIF R-STDP integ=euler seed=0 dt=0.005 T=2000 ===
# debug: h_count mean 10.512451171875 o_count mean 3.0140626430511475 H {'mean_spike_rate': 0.0052562255859375, 'silent_frac': 0.9947437744140625, 'active_frac': 0.0052562255859375} O {'mean_spike_rate': 0.00150703125, 'silent_frac': 0.99849296875, 'active_frac': 0.00150703125} no_spike_out 0.000
