# %%
def LZ77_encode(text, window_size=5):
    compressed = []
    pointer = 0

    while pointer < len(text):
        max_match = ''
        length = 0
        i = 1
        tmptext = text[pointer]
        buffer = text[max(0, pointer - window_size):pointer]
        if len(tmptext) < len(buffer):
            while True:
                if (buffer + text[pointer:pointer+max(0, len(tmptext) - len(buffer) + buffer.find(tmptext[0]))]).find(tmptext) != -1 and \
                pointer + i < len(text) + 1:
                    length += 1
                    max_match = tmptext
                    tmptext = text[pointer:pointer+i+1]
                else:
                    break
                i += 1

        if length > 0:
            next_char = text[pointer + length] if pointer + length < len(text) else ''
            offset = len(buffer) - buffer.find(tmptext[0])
            compressed.append((offset, length, next_char))
            pointer += length + 1
        else:
            compressed.append((0, 0, text[pointer]))
            pointer += 1
    compressed[-1] = compressed[-1][0:2] + ('$',)

    return compressed

# %%
def LZ77_decode(compressed):
    text = ''
    for item in compressed:
        offset, length, char = item
        if length == 0:
            text += char
        else:
            start = len(text) - offset
            for i in range(length):
                text += text[start + i]
            text += char
    return text

# %%
# Пример использования:
input_string = "abracadabra"
encoded_string = LZ77_encode(input_string)
print("Encoded string:", encoded_string)
decoded_string = LZ77_decode(encoded_string)
print("Decoded string:", decoded_string)

input_string = "abacabacabadaca"
encoded_string = LZ77_encode(input_string)
print("Encoded string:", encoded_string)
decoded_string = LZ77_decode(encoded_string)
print("Decoded string:", decoded_string)
# Out:
# Encoded string: [(0, 0, 'a'), (0, 0, 'b'), (0, 0, 'r'), (3, 1, 'c'), (5, 1, 'd'), (4, 1, 'b'), (0, 0, 'r'), (5, 1, '$')]
# Decoded string: abracadabra$
# Encoded string: [(0, 0, 'a'), (0, 0, 'b'), (2, 1, 'c'), (4, 7, 'd'), (4, 1, 'c'), (4, 1, '$')]
# Decoded string: abacabacabadaca$

# %%
def LZ77_to_file(filename, encoded_data):
    with open(filename, 'wb') as file:
        for item in encoded_data:
            file.write(item[0].to_bytes(2, byteorder='big'))
            file.write(item[1].to_bytes(2, byteorder='big'))
            file.write(ord(item[2]).to_bytes(2, byteorder='big'))
    return

# %%
def LZ77_from_file(filename):
    with open(filename, 'rb') as file:
        encoded_data = []
        while True:
            offset = file.read(2)
            if not offset:
                break
            offset = int.from_bytes(offset, "big")
            length = int.from_bytes(file.read(2), "big")
            next_char = chr(int.from_bytes(file.read(2), "big"))
            encoded_data.append((offset, length, next_char))
    return encoded_data

# %%
def read_from_file(filename):
    string = ''
    with open(filename, "r", encoding='utf-8') as file:
        for line in file:
            string += line
    return string

# %%
string = read_from_file('harry_potter_and_the_prisoner_of_azkaban_and_harry_potter_and_the_sorcerers_stone.txt')

# %%
encoded_string = LZ77_encode(string, window_size=60000)

# %%
LZ77_to_file('encoded_harry_potter_and_the_prisoner_of_azkaban_and_harry_potter_and_the_sorcerers_stone.txt', encoded_string)

# %%
encoded_string_from_file = LZ77_from_file('encoded_harry_potter_and_the_prisoner_of_azkaban_and_harry_potter_and_the_sorcerers_stone.txt')

# %%
LZ77_decode(encoded_string_from_file)
# Out:
# ' \n  \n   Harry Potter and the Prisoner of Azkabar\n \n  \n\n \n To Jill Poewett arryAinerKiely,\n  \n hergodmothers \n  Swing\n  \n   Har\n \n  1. OWL \nOST\n  \n   HHarry Potter was \n highll unusual boy in many \n ys. For \nnertheng, \ne \nattd \n  \nsummerrholidarr morer aandand otter timo oneyear. of Aarott a, \n  rewlll warteweto dodhis armewodkrKut wingfodcergodmothithingsecrrt, inuthigderdr\n \nnight. And  \n alsottappenud wasbert \nizald.\n   Itheng,nertly menneng,, Fod \nnewattlring \nn \natts\n mach idaber, moreblankersdarawndrimo  ovo  t a, ear.lik a, t at, \n flwlhllghisingong hinrgangse lsrgerKeithirgfoungsbdok (A Hint\nry o \nMrgicgdygBrdrildalBals ow) ploppedttpen t aizsthtg,,pizl\nw. Hatry movod menntep FodhingeFolnefer, morquila rowndth idamo,abrovoingebsdar liok ddrorisomott nght et.wonlrgh lplhlm \nrltg hint\nsnay,g"Winch Burnint\ningsbdoFourt\nentriCedtury WrgiC\nrpldtedygPoin ledt Dilcuss."\n   Tg,,quila ptused athtg,,t\np,piza Hik ly lovoindtpFrForFph.dHFory,puiher,hilarownroglasdesdudatar brodgeebsdh ngnis ,dmovott nghflrghlrg t.clrs rgh  tg hioou, hnd r\nad:\n   \n Bu Non-ratic peouldo(rpr\nec\nrm\nrly kn wn tu Mugdted)gwede Diltilularla airtid oizmtusedindmedi,val,timos,dbut Hit verytpoodtptdHFcognizilg,pt.,Onrthilraseogccasibs taatatary dodgcrgch r rghldmit.clorgwngard, hnrndntihhn nd  fiect hhhnsoeval. Thilwic peouldo(rpr wougdo(erfprmec\nbtu c FtemedFdeezilg,Chirmtund thin aretedd oo shrsekdindhdiai, miile,tnjiyizila Hentld,tpicklinizsFcsasigc.,Inreid, Wilreldm taa Wiirghendntedobghntibnrned,sormnccltclo soe hlgohen h fs ff nd b fchughnsnoelesu c pnlfouty-u verft mer  c vc\nipuu d sgu ces.\nd d\ndFdHirry authhse qnrll bgtineddhsektekthda,  reaciid unjirnjatldhizipickoh f n aa Winkzsostld lo sa Woldmof plocama t. Slgolteandnvedyibnrefnllgohe unscrewe htoe inoelesu c, ndpaed h mer  c vinooelt, anlfb gc\n t mw\niter pc